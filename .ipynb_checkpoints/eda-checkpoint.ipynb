# %%
import json
import pandas as pd

data = json.load(open('data.json', encoding = 'cp850'))

keys = {}
for objects in data["RECDATA"]:
    key = objects["FacilityID"]
    keys[key] = objects

keys
# Out:
# {'232446': {'CampsiteID': '9',
#   'FacilityID': '232446',
#   'CampsiteName': '074',
#   'CampsiteType': 'RV NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -119.684413373,
#   'CampsiteLatitude': 37.5501406760001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232447': {'CampsiteID': '99',
#   'FacilityID': '232447',
#   'CampsiteName': '043',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Upper Pines',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -119.565204195,
#   'CampsiteLatitude': 37.737337763,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232451': {'CampsiteID': '999',
#   'FacilityID': '232451',
#   'CampsiteName': '073: HIKE-IN',
#   'CampsiteType': 'HIKE TO',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Hodgdon Campground',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -119.866181881,
#   'CampsiteLatitude': 37.799665776,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-09-29'},
#  '232709': {'CampsiteID': '9999',
#   'FacilityID': '232709',
#   'CampsiteName': '38',
#   'CampsiteType': 'RV ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'REYNOLDS CREEK ',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -97.270297,
#   'CampsiteLatitude': 31.588458,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-09-14'},
#  '251938': {'CampsiteID': '99987',
#   'FacilityID': '251938',
#   'CampsiteName': '019',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'THUNDER ROCK CAMPGROUND',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -84.486729,
#   'CampsiteLatitude': 35.076754,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2022-06-29'},
#  '251945': {'CampsiteID': '99999',
#   'FacilityID': '251945',
#   'CampsiteName': 'H001',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'H',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -75.5398617289999,
#   'CampsiteLatitude': 35.2367096290001,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2022-11-16'},
#  '250877': {'CampsiteID': '94871',
#   'FacilityID': '250877',
#   'CampsiteName': 'F-Burro',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Sites',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -115.3828208,
#   'CampsiteLatitude': 36.13192082,
#   'CreatedDate': '2014-10-30',
#   'LastUpdatedDate': '2023-09-22'},
#  '252470': {'CampsiteID': '99997',
#   'FacilityID': '252470',
#   'CampsiteName': '02',
#   'CampsiteType': 'GROUP TENT ONLY AREA NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dundo Group Campground',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -78.71703178,
#   'CampsiteLatitude': 38.2356493030001,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2022-06-29'},
#  '232458': {'CampsiteID': '893',
#   'FacilityID': '232458',
#   'CampsiteName': '416',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 4',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -86.113284601,
#   'CampsiteLatitude': 44.7166249140001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233098': {'CampsiteID': '13535',
#   'FacilityID': '233098',
#   'CampsiteName': 'B37',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -92.429835,
#   'CampsiteLatitude': 34.830454,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233119': {'CampsiteID': '91984',
#   'FacilityID': '233119',
#   'CampsiteName': 'G3',
#   'CampsiteType': 'GROUP TENT ONLY AREA NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Sites',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -92.762207315,
#   'CampsiteLatitude': 35.9888994730001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10001419': {'CampsiteID': '10001431',
#   'FacilityID': '10001419',
#   'CampsiteName': '13',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '2',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -103.491094,
#   'CampsiteLatitude': 43.460221,
#   'CreatedDate': '2019-01-18',
#   'LastUpdatedDate': '2022-05-05'},
#  '10001432': {'CampsiteID': '10001450',
#   'FacilityID': '10001432',
#   'CampsiteName': '18',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '1',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -103.572206,
#   'CampsiteLatitude': 43.439841,
#   'CreatedDate': '2019-01-18',
#   'LastUpdatedDate': '2022-05-05'},
#  '10001451': {'CampsiteID': '10001490',
#   'FacilityID': '10001451',
#   'CampsiteName': '39 - Horse Site',
#   'CampsiteType': 'EQUESTRIAN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Horse Camp',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -93.338822,
#   'CampsiteLatitude': 36.039256,
#   'CreatedDate': '2019-01-22',
#   'LastUpdatedDate': '2021-05-19'},
#  '259242': {'CampsiteID': '10001579',
#   'FacilityID': '259242',
#   'CampsiteName': '89',
#   'CampsiteType': 'RV NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-01-24',
#   'LastUpdatedDate': '2023-09-24'},
#  '270967': {'CampsiteID': '10001664',
#   'FacilityID': '270967',
#   'CampsiteName': '26',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -71.7943192712747,
#   'CampsiteLatitude': 44.0765720404814,
#   'CreatedDate': '2019-01-28',
#   'LastUpdatedDate': '2020-10-15'},
#  '233478': {'CampsiteID': '10003',
#   'FacilityID': '233478',
#   'CampsiteName': '1',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'DAM EAST SPILLWAY',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -89.3544,
#   'CampsiteLatitude': 38.616093,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10003362': {'CampsiteID': '10003400',
#   'FacilityID': '10003362',
#   'CampsiteName': '038',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.705469,
#   'CampsiteLatitude': 46.653242,
#   'CreatedDate': '2019-02-21',
#   'LastUpdatedDate': '2022-06-29'},
#  '10003401': {'CampsiteID': '10003418',
#   'FacilityID': '10003401',
#   'CampsiteName': '017',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.684215,
#   'CampsiteLatitude': 46.643803,
#   'CreatedDate': '2019-02-21',
#   'LastUpdatedDate': '2022-05-19'},
#  '10003508': {'CampsiteID': '10003509',
#   'FacilityID': '10003508',
#   'CampsiteName': 'Eagleview Shelter',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.181022,
#   'CampsiteLatitude': 32.917917,
#   'CreatedDate': '2019-02-28',
#   'LastUpdatedDate': '2021-02-05'},
#  '239417': {'CampsiteID': '10004003',
#   'FacilityID': '239417',
#   'CampsiteName': '28',
#   'CampsiteType': 'WALK TO',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -71.5576273259292,
#   'CampsiteLatitude': 44.047635697719,
#   'CreatedDate': '2019-03-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '261696': {'CampsiteID': '10180274',
#   'FacilityID': '261696',
#   'CampsiteName': 'Group Use Shelter',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'HolterLake',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2022-03-24',
#   'LastUpdatedDate': '2022-06-29'},
#  '258887': {'CampsiteID': '10004146',
#   'FacilityID': '258887',
#   'CampsiteName': '67',
#   'CampsiteType': 'TENT ONLY NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Douglas',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-03-20',
#   'LastUpdatedDate': '2022-08-22'},
#  '264411': {'CampsiteID': '10281594',
#   'FacilityID': '264411',
#   'CampsiteName': 'S&P Site Type 0',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan & Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2023-07-12',
#   'LastUpdatedDate': '2023-09-22'},
#  '10004152': {'CampsiteID': '10163087',
#   'FacilityID': '10004152',
#   'CampsiteName': 'Scan and Pay 6 ',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Camp 4',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-20',
#   'LastUpdatedDate': '2022-01-13'},
#  '273785': {'CampsiteID': '10004299',
#   'FacilityID': '273785',
#   'CampsiteName': '33',
#   'CampsiteType': 'GROUP STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.089199,
#   'CampsiteLatitude': 47.267325,
#   'CreatedDate': '2019-03-26',
#   'LastUpdatedDate': '2021-09-16'},
#  '10004358': {'CampsiteID': '10004382',
#   'FacilityID': '10004358',
#   'CampsiteName': '24',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -84.6343188979999,
#   'CampsiteLatitude': 36.5456172220972,
#   'CreatedDate': '2019-03-26',
#   'LastUpdatedDate': '2022-06-16'},
#  '247867': {'CampsiteID': '10004432',
#   'FacilityID': '247867',
#   'CampsiteName': '24',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.122723,
#   'CampsiteLatitude': 39.321021,
#   'CreatedDate': '2019-03-28',
#   'LastUpdatedDate': '2020-11-10'},
#  '273308': {'CampsiteID': '10004455',
#   'FacilityID': '273308',
#   'CampsiteName': '21',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Camp Loop',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -123.5703,
#   'CampsiteLatitude': 43.90443,
#   'CreatedDate': '2019-03-28',
#   'LastUpdatedDate': '2023-07-11'},
#  '10004589': {'CampsiteID': '10004591',
#   'FacilityID': '10004589',
#   'CampsiteName': 'Earl Cook 2',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.174661,
#   'CampsiteLatitude': 32.993756,
#   'CreatedDate': '2019-04-02',
#   'LastUpdatedDate': '2021-05-25'},
#  '10004592': {'CampsiteID': '10004593',
#   'FacilityID': '10004592',
#   'CampsiteName': 'Hardley Creek Shelter',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.191762,
#   'CampsiteLatitude': 32.917472,
#   'CreatedDate': '2019-04-02',
#   'LastUpdatedDate': '2021-02-11'},
#  '10004594': {'CampsiteID': '10106593',
#   'FacilityID': '10004594',
#   'CampsiteName': 'Horace King Shelter #2',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-01-08',
#   'LastUpdatedDate': '2022-02-07'},
#  '10004596': {'CampsiteID': '10106594',
#   'FacilityID': '10004596',
#   'CampsiteName': 'Long Cane Shelter #2',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-01-08',
#   'LastUpdatedDate': '2021-02-09'},
#  '10004598': {'CampsiteID': '10004599',
#   'FacilityID': '10004598',
#   'CampsiteName': 'McGee Bridge Shelter',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.119329,
#   'CampsiteLatitude': 33.058737,
#   'CreatedDate': '2019-04-02',
#   'LastUpdatedDate': '2021-05-25'},
#  '10004600': {'CampsiteID': '10106596',
#   'FacilityID': '10004600',
#   'CampsiteName': 'Rocky Point Shelter #3',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-01-08',
#   'LastUpdatedDate': '2021-07-20'},
#  '10004602': {'CampsiteID': '10106597',
#   'FacilityID': '10004602',
#   'CampsiteName': 'Veasey Creek Shelter #2',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-01-08',
#   'LastUpdatedDate': '2022-05-26'},
#  '10004604': {'CampsiteID': '10004605',
#   'FacilityID': '10004604',
#   'CampsiteName': 'Yellowjacket Shelter',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.102748,
#   'CampsiteLatitude': 33.075072,
#   'CreatedDate': '2019-04-02',
#   'LastUpdatedDate': '2021-05-25'},
#  '10004657': {'CampsiteID': '10004658',
#   'FacilityID': '10004657',
#   'CampsiteName': 'Bay View House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -70.074826,
#   'CampsiteLatitude': 41.958112,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2022-05-10'},
#  '10004659': {'CampsiteID': '10004660',
#   'FacilityID': '10004659',
#   'CampsiteName': 'Beach View House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -69.948381,
#   'CampsiteLatitude': 41.847716,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2022-05-10'},
#  '10004661': {'CampsiteID': '10004662',
#   'FacilityID': '10004661',
#   'CampsiteName': 'Le Count Beach House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -69.978996,
#   'CampsiteLatitude': 41.922798,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2022-12-10'},
#  '10004663': {'CampsiteID': '10004664',
#   'FacilityID': '10004663',
#   'CampsiteName': 'Ocean View House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -69.977201,
#   'CampsiteLatitude': 41.926892,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2020-10-15'},
#  '10004665': {'CampsiteID': '10004666',
#   'FacilityID': '10004665',
#   'CampsiteName': 'Seashore Modern House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -69.993971,
#   'CampsiteLatitude': 41.958068,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2020-10-15'},
#  '10004667': {'CampsiteID': '10004668',
#   'FacilityID': '10004667',
#   'CampsiteName': 'Sunrise House',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -69.977154,
#   'CampsiteLatitude': 41.925892,
#   'CreatedDate': '2019-04-04',
#   'LastUpdatedDate': '2022-05-10'},
#  '233136': {'CampsiteID': '79986',
#   'FacilityID': '233136',
#   'CampsiteName': 'GS1',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Anthony Lake',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -118.2294824,
#   'CampsiteLatitude': 44.96239081,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233392': {'CampsiteID': '91918',
#   'FacilityID': '233392',
#   'CampsiteName': '15',
#   'CampsiteType': 'RV NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Point Supreme CG',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -112.830973039,
#   'CampsiteLatitude': 37.60972918,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10004919': {'CampsiteID': '10004931',
#   'FacilityID': '10004919',
#   'CampsiteName': '86',
#   'CampsiteType': 'YURT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Glamping',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-04-11',
#   'LastUpdatedDate': '2022-07-20'},
#  '10004932': {'CampsiteID': '10004940',
#   'FacilityID': '10004932',
#   'CampsiteName': '8',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Gorge Lake',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -121.151789738,
#   'CampsiteLatitude': 48.7159041790001,
#   'CreatedDate': '2019-04-11',
#   'LastUpdatedDate': '2023-03-04'},
#  '232010': {'CampsiteID': '60985',
#   'FacilityID': '232010',
#   'CampsiteName': '012',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ALBI',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.611879547035,
#   'CampsiteLatitude': 40.5747020379457,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '245489': {'CampsiteID': '10005252',
#   'FacilityID': '245489',
#   'CampsiteName': '32',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -119.989090849415,
#   'CampsiteLatitude': 38.4808292975905,
#   'CreatedDate': '2019-04-22',
#   'LastUpdatedDate': '2020-10-15'},
#  '10005253': {'CampsiteID': '10005278',
#   'FacilityID': '10005253',
#   'CampsiteName': '25',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.006835696099,
#   'CampsiteLatitude': 38.477414866341,
#   'CreatedDate': '2019-04-22',
#   'LastUpdatedDate': '2020-12-15'},
#  '10005279': {'CampsiteID': '10005281',
#   'FacilityID': '10005279',
#   'CampsiteName': 'Overlook Shelter',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-04-22',
#   'LastUpdatedDate': '2023-06-02'},
#  '273310': {'CampsiteID': '10005283',
#   'FacilityID': '273310',
#   'CampsiteName': 'Shelter 2',
#   'CampsiteType': 'GROUP STANDARD ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shelter Area',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -122.847,
#   'CampsiteLatitude': 44.231,
#   'CreatedDate': '2019-04-22',
#   'LastUpdatedDate': '2022-04-06'},
#  '232404': {'CampsiteID': '46981',
#   'FacilityID': '232404',
#   'CampsiteName': 'XXX2',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MANAGEMENT SITES',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233462': {'CampsiteID': '13699',
#   'FacilityID': '233462',
#   'CampsiteName': '01',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CDEA',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -95.71808,
#   'CampsiteLatitude': 38.499435,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10005349': {'CampsiteID': '10180251',
#   'FacilityID': '10005349',
#   'CampsiteName': 'Shade Shelter 3',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'Beach',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2022-03-24',
#   'LastUpdatedDate': '2022-03-25'},
#  '10005351': {'CampsiteID': '10005352',
#   'FacilityID': '10005351',
#   'CampsiteName': 'Blue Lake Group Site',
#   'CampsiteType': 'GROUP RV AREA NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Horseshoe Loop',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-04-25',
#   'LastUpdatedDate': '2021-08-23'},
#  '10005354': {'CampsiteID': '10005356',
#   'FacilityID': '10005354',
#   'CampsiteName': 'Green Shelter',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -83.535411,
#   'CampsiteLatitude': 38.117062,
#   'CreatedDate': '2019-04-25',
#   'LastUpdatedDate': '2022-04-18'},
#  '233834': {'CampsiteID': '51970',
#   'FacilityID': '233834',
#   'CampsiteName': '012',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -93.6247512849671,
#   'CampsiteLatitude': 35.2262307278557,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10005358': {'CampsiteID': '10005359',
#   'FacilityID': '10005358',
#   'CampsiteName': 'Somerfield North Recreation Area',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -79.3937,
#   'CampsiteLatitude': 39.7566,
#   'CreatedDate': '2019-04-25',
#   'LastUpdatedDate': '2022-06-29'},
#  '261822': {'CampsiteID': '10180954',
#   'FacilityID': '261822',
#   'CampsiteName': 'Small Group Shelter 2',
#   'CampsiteType': 'RV NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'Beach',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2022-03-28',
#   'LastUpdatedDate': '2022-05-09'},
#  '10005414': {'CampsiteID': '10005415',
#   'FacilityID': '10005414',
#   'CampsiteName': 'Rock Creek Guard Station',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-04-30',
#   'LastUpdatedDate': '2023-08-08'},
#  '247603': {'CampsiteID': '10005580',
#   'FacilityID': '247603',
#   'CampsiteName': '10',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Upper',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-06',
#   'LastUpdatedDate': '2022-11-16'},
#  '246856': {'CampsiteID': '10005588',
#   'FacilityID': '246856',
#   'CampsiteName': '8',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-06',
#   'LastUpdatedDate': '2022-12-24'},
#  '247602': {'CampsiteID': '10278899',
#   'FacilityID': '247602',
#   'CampsiteName': 'Twelvemile Cabin',
#   'CampsiteType': 'CABIN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cabin',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2023-06-20',
#   'LastUpdatedDate': '2023-06-28'},
#  '232406': {'CampsiteID': '41972',
#   'FacilityID': '232406',
#   'CampsiteName': '7',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'South',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.448962,
#   'CampsiteLatitude': 37.8794100000001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233346': {'CampsiteID': '78975',
#   'FacilityID': '233346',
#   'CampsiteName': '01',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ACKERMAN CAMPGROUND',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.772658,
#   'CampsiteLatitude': 40.786092,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232753': {'CampsiteID': '67829',
#   'FacilityID': '232753',
#   'CampsiteName': '044',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA ANTLERS',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.377508,
#   'CampsiteLatitude': 40.8884440000001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '249579': {'CampsiteID': '10005867',
#   'FacilityID': '249579',
#   'CampsiteName': '8',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -90.7151606459174,
#   'CampsiteLatitude': 46.0381244853386,
#   'CreatedDate': '2019-05-10',
#   'LastUpdatedDate': '2020-10-15'},
#  '264686': {'CampsiteID': '10005868',
#   'FacilityID': '264686',
#   'CampsiteName': 'Rocky Bend Group Site',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -123.6060299,
#   'CampsiteLatitude': 45.2396210000001,
#   'CreatedDate': '2019-05-10',
#   'LastUpdatedDate': '2021-04-06'},
#  '250796': {'CampsiteID': '94306',
#   'FacilityID': '250796',
#   'CampsiteName': '04',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Davis Bayou Campground',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -88.7962719879999,
#   'CampsiteLatitude': 30.397648657,
#   'CreatedDate': '2014-06-19',
#   'LastUpdatedDate': '2022-06-29'},
#  '232761': {'CampsiteID': '87990',
#   'FacilityID': '232761',
#   'CampsiteName': '014',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA ELLERY CREEK',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.242532,
#   'CampsiteLatitude': 40.9155430000001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232234': {'CampsiteID': '64984',
#   'FacilityID': '232234',
#   'CampsiteName': 'XXX10',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA HAYWARD FLAT',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232758': {'CampsiteID': '85960',
#   'FacilityID': '232758',
#   'CampsiteName': '018',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA LAKESHORE EAST',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.389063117981,
#   'CampsiteLatitude': 40.8712343313946,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232235': {'CampsiteID': '68000',
#   'FacilityID': '232235',
#   'CampsiteName': '031',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'D',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.843152,
#   'CampsiteLatitude': 40.8340680000001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '234544': {'CampsiteID': '68998',
#   'FacilityID': '234544',
#   'CampsiteName': '004',
#   'CampsiteType': 'TENT ONLY NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA WILD PLUM',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.603332641,
#   'CampsiteLatitude': 39.5665002200002,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10005977': {'CampsiteID': '10006106',
#   'FacilityID': '10005977',
#   'CampsiteName': 'Group Shelter',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-20',
#   'LastUpdatedDate': '2023-06-07'},
#  '232524': {'CampsiteID': '17138',
#   'FacilityID': '232524',
#   'CampsiteName': '25',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BIG COON CREEK ',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -94.240646,
#   'CampsiteLatitude': 34.225634,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-08-16'},
#  '232566': {'CampsiteID': '11652',
#   'FacilityID': '232566',
#   'CampsiteName': 'C04',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BUCK',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -83.469822,
#   'CampsiteLatitude': 37.344117,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233695': {'CampsiteID': '37957',
#   'FacilityID': '233695',
#   'CampsiteName': '104',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B-LO',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -95.70934,
#   'CampsiteLatitude': 38.516225,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '239632': {'CampsiteID': '10006146',
#   'FacilityID': '239632',
#   'CampsiteName': '1',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-22',
#   'LastUpdatedDate': '2021-07-20'},
#  '10006149': {'CampsiteID': '10006150',
#   'FacilityID': '10006149',
#   'CampsiteName': 'Overlook Day Use Area',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shelter',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-22',
#   'LastUpdatedDate': '2022-04-18'},
#  '10006204': {'CampsiteID': '10006205',
#   'FacilityID': '10006204',
#   'CampsiteName': 'Beaver Creek Cabin',
#   'CampsiteType': 'CABIN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-24',
#   'LastUpdatedDate': '2020-10-15'},
#  '10006206': {'CampsiteID': '10006207',
#   'FacilityID': '10006206',
#   'CampsiteName': 'Moon Lake Guard Station Cabin',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-05-24',
#   'LastUpdatedDate': '2021-07-06'},
#  '10006208': {'CampsiteID': '10006209',
#   'FacilityID': '10006208',
#   'CampsiteName': 'Joe Thompson Cabin',
#   'CampsiteType': 'CABIN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -154.04274,
#   'CampsiteLatitude': 60.34805,
#   'CreatedDate': '2019-05-24',
#   'LastUpdatedDate': '2021-05-12'},
#  '267551': {'CampsiteID': '102564',
#   'FacilityID': '267551',
#   'CampsiteName': '025',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C Loop',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2017-08-03',
#   'LastUpdatedDate': '2022-06-29'},
#  '233596': {'CampsiteID': '39980',
#   'FacilityID': '233596',
#   'CampsiteName': '010',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PRIV',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.892035,
#   'CampsiteLatitude': 48.180184,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2023-02-15'},
#  '233600': {'CampsiteID': '17818',
#   'FacilityID': '233600',
#   'CampsiteName': '005',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'NIGH',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.770085,
#   'CampsiteLatitude': 48.161208,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2023-02-15'},
#  '233637': {'CampsiteID': '99539',
#   'FacilityID': '233637',
#   'CampsiteName': '38',
#   'CampsiteType': 'WALK TO',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CEDA',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.5892,
#   'CampsiteLatitude': 48.235927,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2023-02-15'},
#  '233551': {'CampsiteID': '72984',
#   'FacilityID': '233551',
#   'CampsiteName': '104',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MCOV',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -99.322666,
#   'CampsiteLatitude': 40.084291,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '251834': {'CampsiteID': '98328',
#   'FacilityID': '251834',
#   'CampsiteName': 'C',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dewey Bridge',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.3071601,
#   'CampsiteLatitude': 38.81112655,
#   'CreatedDate': '2016-02-04',
#   'LastUpdatedDate': '2022-06-29'},
#  '273975': {'CampsiteID': '10006430',
#   'FacilityID': '273975',
#   'CampsiteName': '18',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.514502223983,
#   'CampsiteLatitude': 47.9340910088438,
#   'CreatedDate': '2019-05-31',
#   'LastUpdatedDate': '2021-01-20'},
#  '251839': {'CampsiteID': '98335',
#   'FacilityID': '251839',
#   'CampsiteName': 'The Ledge Group Site',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'The Ledge Group Site',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.6021889,
#   'CampsiteLatitude': 38.4810806,
#   'CreatedDate': '2016-02-04',
#   'LastUpdatedDate': '2023-03-06'},
#  '10007130': {'CampsiteID': '10007143',
#   'FacilityID': '10007130',
#   'CampsiteName': '3',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B unit',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2021-07-14'},
#  '246027': {'CampsiteID': '10007144',
#   'FacilityID': '246027',
#   'CampsiteName': 'Hilltop Hideaway',
#   'CampsiteType': 'CABIN ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '249981': {'CampsiteID': '63437153',
#   'FacilityID': '249981',
#   'CampsiteName': 'Ingersoll Cove',
#   'CampsiteType': 'BOAT IN',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sand Point Lake',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -92.47668539,
#   'CampsiteLatitude': 48.35082528,
#   'CreatedDate': '2018-06-18',
#   'LastUpdatedDate': '2022-09-13'},
#  '233591': {'CampsiteID': '25830',
#   'FacilityID': '233591',
#   'CampsiteName': '15',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'POAP',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -95.968455,
#   'CampsiteLatitude': 36.899083,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232083': {'CampsiteID': '99555',
#   'FacilityID': '232083',
#   'CampsiteName': '071',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 2 MEADOW ',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.405083,
#   'CampsiteLatitude': 38.867917,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2023-08-10'},
#  '10007154': {'CampsiteID': '10007155',
#   'FacilityID': '10007154',
#   'CampsiteName': 'Hemlock Shelter',
#   'CampsiteType': 'GROUP STANDARD AREA NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '10007156': {'CampsiteID': '10007159',
#   'FacilityID': '10007156',
#   'CampsiteName': '3',
#   'CampsiteType': 'SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '10007160': {'CampsiteID': '10007161',
#   'FacilityID': '10007160',
#   'CampsiteName': 'Spyglass Cabin',
#   'CampsiteType': 'CABIN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.196980915198,
#   'CampsiteLatitude': 47.8420733512787,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '233146': {'CampsiteID': '82969',
#   'FacilityID': '233146',
#   'CampsiteName': '020',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRESCENT LAKE (MN)',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -90.7739908284034,
#   'CampsiteLatitude': 47.8285995428991,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10007179': {'CampsiteID': '10007180',
#   'FacilityID': '10007179',
#   'CampsiteName': 'Leatherwood Shelter',
#   'CampsiteType': 'GROUP STANDARD AREA NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2020-10-15'},
#  '246520': {'CampsiteID': '10167905',
#   'FacilityID': '246520',
#   'CampsiteName': 'S&P Standard Nonelectric',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2022-01-14',
#   'LastUpdatedDate': '2022-01-22'},
#  '233809': {'CampsiteID': '53999',
#   'FacilityID': '233809',
#   'CampsiteName': 'S-12',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CMPG',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -83.36866667,
#   'CampsiteLatitude': 37.27372778,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10007207': {'CampsiteID': '10007215',
#   'FacilityID': '10007207',
#   'CampsiteName': '8',
#   'CampsiteType': 'SHELTER NONELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-06-18',
#   'LastUpdatedDate': '2022-08-15'},
#  '233507': {'CampsiteID': '69000',
#   'FacilityID': '233507',
#   'CampsiteName': '71',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HERNANDO POINT ',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -90.065917,
#   'CampsiteLatitude': 34.732354,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233684': {'CampsiteID': '58997',
#   'FacilityID': '233684',
#   'CampsiteName': '28',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SOUTH ABUTMENT',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -90.12686,
#   'CampsiteLatitude': 34.747003,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233434': {'CampsiteID': '96652',
#   'FacilityID': '233434',
#   'CampsiteName': 'PAV 1',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Day',
#   'Loop': 'BRADY MOUNTAIN',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -93.265692,
#   'CampsiteLatitude': 34.58058,
#   'CreatedDate': '2015-04-23',
#   'LastUpdatedDate': '2022-09-01'},
#  '253491': {'CampsiteID': '100075',
#   'FacilityID': '253491',
#   'CampsiteName': 'GRANITE BUTTE LOOKOUT',
#   'CampsiteType': 'LOOKOUT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRANITE BUTTE LOOKOUT',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -112.464766667,
#   'CampsiteLatitude': 46.8630166667,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2022-06-29'},
#  '233456': {'CampsiteID': '37711',
#   'FacilityID': '233456',
#   'CampsiteName': '53',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CHICKASAW HILL',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -89.821431,
#   'CampsiteLatitude': 34.166414,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '233662': {'CampsiteID': '460501',
#   'FacilityID': '233662',
#   'CampsiteName': 'MP620',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Day',
#   'Loop': 'MCCURDY POINT\t',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2018-06-26',
#   'LastUpdatedDate': '2020-10-15'},
#  '249312': {'CampsiteID': '10011185',
#   'FacilityID': '249312',
#   'CampsiteName': 'T18',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CANE',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.200813733,
#   'CampsiteLatitude': 33.7298267050001,
#   'CreatedDate': '2019-09-18',
#   'LastUpdatedDate': '2021-01-20'},
#  '249291': {'CampsiteID': '10007762',
#   'FacilityID': '249291',
#   'CampsiteName': '205',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mesquite',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.011587281,
#   'CampsiteLatitude': 33.650348878,
#   'CreatedDate': '2019-07-01',
#   'LastUpdatedDate': '2022-10-25'},
#  '249308': {'CampsiteID': '10009032',
#   'FacilityID': '249308',
#   'CampsiteName': '322',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COYOTE',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-07-30',
#   'LastUpdatedDate': '2020-10-15'},
#  '232003': {'CampsiteID': '282033',
#   'FacilityID': '232003',
#   'CampsiteName': 'XXX',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MANAGEMENT SITES',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2018-06-26',
#   'LastUpdatedDate': '2022-02-23'},
#  '232572': {'CampsiteID': '43993',
#   'FacilityID': '232572',
#   'CampsiteName': '021',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LAKE',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -85.910847,
#   'CampsiteLatitude': 36.300895,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '232355': {'CampsiteID': '73998',
#   'FacilityID': '232355',
#   'CampsiteName': '013',
#   'CampsiteType': 'EQUESTRIAN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MULE',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.311039374,
#   'CampsiteLatitude': 34.270934976,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2023-02-15'},
#  '233379': {'CampsiteID': '91994',
#   'FacilityID': '233379',
#   'CampsiteName': 'B03',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -77.417580938,
#   'CampsiteLatitude': 38.599708956,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '251838': {'CampsiteID': '98307',
#   'FacilityID': '251838',
#   'CampsiteName': 'E',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Horsethief',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.813053760211,
#   'CampsiteLatitude': 38.5841280877091,
#   'CreatedDate': '2016-02-04',
#   'LastUpdatedDate': '2022-06-30'},
#  '255118': {'CampsiteID': '101049',
#   'FacilityID': '255118',
#   'CampsiteName': 'Group B',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower Onion Creek Group Site',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.360819,
#   'CampsiteLatitude': 38.736884,
#   'CreatedDate': '2017-01-12',
#   'LastUpdatedDate': '2022-06-29'},
#  '10008944': {'CampsiteID': '10008963',
#   'FacilityID': '10008944',
#   'CampsiteName': '19',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -120.956405351941,
#   'CampsiteLatitude': 40.1577780764595,
#   'CreatedDate': '2019-07-30',
#   'LastUpdatedDate': '2021-06-05'},
#  '251969': {'CampsiteID': '100092',
#   'FacilityID': '251969',
#   'CampsiteName': 'Bermuda',
#   'CampsiteType': 'WALK TO',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BERMUDA CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -86.6461638889,
#   'CampsiteLatitude': 46.4711194444001,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2023-07-14'},
#  '240242': {'CampsiteID': '10009262',
#   'FacilityID': '240242',
#   'CampsiteName': '23',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -83.913649678098,
#   'CampsiteLatitude': 34.709380138647,
#   'CreatedDate': '2019-08-06',
#   'LastUpdatedDate': '2020-10-15'},
#  '231979': {'CampsiteID': '99626',
#   'FacilityID': '231979',
#   'CampsiteName': 'J02',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop J',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.13880688057,
#   'CampsiteLatitude': 43.1353182869493,
#   'CreatedDate': '2016-12-08',
#   'LastUpdatedDate': '2022-06-29'},
#  '251544': {'CampsiteID': '98757',
#   'FacilityID': '251544',
#   'CampsiteName': '004',
#   'CampsiteType': 'GROUP TENT ONLY AREA NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Marsden Tract Group Campsite',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -77.217908644,
#   'CampsiteLatitude': 38.976659205,
#   'CreatedDate': '2016-03-03',
#   'LastUpdatedDate': '2022-06-29'},
#  '232670': {'CampsiteID': '50983',
#   'FacilityID': '232670',
#   'CampsiteName': 'C27',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -90.768003,
#   'CampsiteLatitude': 37.143465,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '231834': {'CampsiteID': '27871',
#   'FacilityID': '231834',
#   'CampsiteName': 'GRP1',
#   'CampsiteType': 'GROUP STANDARD AREA NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'West',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -107.500081,
#   'CampsiteLatitude': 44.5453000000001,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10009517': {'CampsiteID': '10009518',
#   'FacilityID': '10009517',
#   'CampsiteName': 'Gazebo',
#   'CampsiteType': 'PICNIC',
#   'TypeOfUse': 'Day',
#   'Loop': 'Box Canyon',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -105.222866246088,
#   'CampsiteLatitude': 41.09444384167,
#   'CreatedDate': '2019-08-12',
#   'LastUpdatedDate': '2020-10-15'},
#  '10009675': {'CampsiteID': '10009676',
#   'FacilityID': '10009675',
#   'CampsiteName': 'Dedication Site Overlook Pavilion',
#   'CampsiteType': 'GROUP SHELTER ELECTRIC',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2019-08-20',
#   'LastUpdatedDate': '2022-06-29'},
#  '249254': {'CampsiteID': '10038711',
#   'FacilityID': '249254',
#   'CampsiteName': '31D',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -111.206438691,
#   'CampsiteLatitude': 33.6273794630002,
#   'CreatedDate': '2019-12-19',
#   'LastUpdatedDate': '2022-05-09'},
#  '10000305': {'CampsiteID': '10009937',
#   'FacilityID': '10000305',
#   'CampsiteName': 'Host Site',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main Access Road',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -113.451829,
#   'CampsiteLatitude': 34.536258,
#   'CreatedDate': '2019-08-23',
#   'LastUpdatedDate': '2020-12-23'},
#  '232746': {'CampsiteID': '46879',
#   'FacilityID': '232746',
#   'CampsiteName': 'F-16',
#   'CampsiteType': 'STANDARD ELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WBEA',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -92.136384,
#   'CampsiteLatitude': 34.70443,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10010172': {'CampsiteID': '10010173',
#   'FacilityID': '10010172',
#   'CampsiteName': '1',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'CampsiteLongitude': -123.23436638353,
#   'CampsiteLatitude': 40.7365624281803,
#   'CreatedDate': '2019-08-28',
#   'LastUpdatedDate': '2020-10-15'},
#  '264886': {'CampsiteID': '10011202',
#   'FacilityID': '264886',
#   'CampsiteName': '19',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -82.8462252658897,
#   'CampsiteLatitude': 35.8615855844044,
#   'CreatedDate': '2019-09-18',
#   'LastUpdatedDate': '2023-02-15'},
#  '257007': {'CampsiteID': '10011388',
#   'FacilityID': '257007',
#   'CampsiteName': 'Super Bowl Group Site',
#   'CampsiteType': 'GROUP SHELTER NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'n/a',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -109.621006,
#   'CampsiteLatitude': 38.145151,
#   'CreatedDate': '2019-09-25',
#   'LastUpdatedDate': '2022-10-28'},
#  '232201': {'CampsiteID': '64965',
#   'FacilityID': '232201',
#   'CampsiteName': '011',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'REED',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -116.900645,
#   'CampsiteLatitude': 48.620866,
#   'CreatedDate': '2014-05-02',
#   'LastUpdatedDate': '2022-06-29'},
#  '10011396': {'CampsiteID': '10011407',
#   'FacilityID': '10011396',
#   'CampsiteName': '11',
#   'CampsiteType': 'EQUESTRIAN NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -82.741403052629,
#   'CampsiteLatitude': 35.3811249585608,
#   'CreatedDate': '2019-09-25',
#   'LastUpdatedDate': '2020-10-15'},
#  '10012078': {'CampsiteID': '10012140',
#   'FacilityID': '10012078',
#   'CampsiteName': '62',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Point Cedar',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -93.3004564,
#   'CampsiteLatitude': 34.27825564,
#   'CreatedDate': '2019-10-04',
#   'LastUpdatedDate': '2023-03-25'},
#  '10012141': {'CampsiteID': '10012142',
#   'FacilityID': '10012141',
# ...
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165435': {'CampsiteID': '10165439',
#   'FacilityID': '10165435',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165440': {'CampsiteID': '10165444',
#   'FacilityID': '10165440',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165445': {'CampsiteID': '10165449',
#   'FacilityID': '10165445',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165450': {'CampsiteID': '10165454',
#   'FacilityID': '10165450',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165455': {'CampsiteID': '10165459',
#   'FacilityID': '10165455',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165460': {'CampsiteID': '10165464',
#   'FacilityID': '10165460',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165465': {'CampsiteID': '10165469',
#   'FacilityID': '10165465',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-15'},
#  '10165470': {'CampsiteID': '10165474',
#   'FacilityID': '10165470',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165475': {'CampsiteID': '10165479',
#   'FacilityID': '10165475',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-15'},
#  '10165480': {'CampsiteID': '10165484',
#   'FacilityID': '10165480',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165485': {'CampsiteID': '10165489',
#   'FacilityID': '10165485',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165490': {'CampsiteID': '10165494',
#   'FacilityID': '10165490',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165495': {'CampsiteID': '10165499',
#   'FacilityID': '10165495',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165500': {'CampsiteID': '10165504',
#   'FacilityID': '10165500',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165505': {'CampsiteID': '10165509',
#   'FacilityID': '10165505',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165510': {'CampsiteID': '10165514',
#   'FacilityID': '10165510',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165515': {'CampsiteID': '10165519',
#   'FacilityID': '10165515',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165520': {'CampsiteID': '10165524',
#   'FacilityID': '10165520',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165525': {'CampsiteID': '10165529',
#   'FacilityID': '10165525',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-06-14'},
#  '10165530': {'CampsiteID': '10165534',
#   'FacilityID': '10165530',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165535': {'CampsiteID': '10165539',
#   'FacilityID': '10165535',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165540': {'CampsiteID': '10165544',
#   'FacilityID': '10165540',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-15'},
#  '10165545': {'CampsiteID': '10165549',
#   'FacilityID': '10165545',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165550': {'CampsiteID': '10165554',
#   'FacilityID': '10165550',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165555': {'CampsiteID': '10165559',
#   'FacilityID': '10165555',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165561': {'CampsiteID': '10165565',
#   'FacilityID': '10165561',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165566': {'CampsiteID': '10240751',
#   'FacilityID': '10165566',
#   'CampsiteName': '010',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Puma',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2023-03-01',
#   'LastUpdatedDate': '2023-04-29'},
#  '10165571': {'CampsiteID': '10165575',
#   'FacilityID': '10165571',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165576': {'CampsiteID': '10165580',
#   'FacilityID': '10165576',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165581': {'CampsiteID': '10165585',
#   'FacilityID': '10165581',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165586': {'CampsiteID': '10165590',
#   'FacilityID': '10165586',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-04-12'},
#  '10165591': {'CampsiteID': '10165595',
#   'FacilityID': '10165591',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165596': {'CampsiteID': '10165600',
#   'FacilityID': '10165596',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165601': {'CampsiteID': '10240724',
#   'FacilityID': '10165601',
#   'CampsiteName': '006',
#   'CampsiteType': 'STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sand Prairie',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2023-03-01',
#   'LastUpdatedDate': '2023-04-29'},
#  '10165606': {'CampsiteID': '10165610',
#   'FacilityID': '10165606',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-04-29'},
#  '10165611': {'CampsiteID': '10165612',
#   'FacilityID': '10165611',
#   'CampsiteName': 'Secret Campground Group',
#   'CampsiteType': 'GROUP STANDARD NONELECTRIC',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Secret',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': -122.441164,
#   'CampsiteLatitude': 43.514789,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2023-06-01'},
#  '10165616': {'CampsiteID': '10165620',
#   'FacilityID': '10165616',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165621': {'CampsiteID': '10165625',
#   'FacilityID': '10165621',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165626': {'CampsiteID': '10165630',
#   'FacilityID': '10165626',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165631': {'CampsiteID': '10165635',
#   'FacilityID': '10165631',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165636': {'CampsiteID': '10165640',
#   'FacilityID': '10165636',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165641': {'CampsiteID': '10165645',
#   'FacilityID': '10165641',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165646': {'CampsiteID': '10165650',
#   'FacilityID': '10165646',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165651': {'CampsiteID': '10165655',
#   'FacilityID': '10165651',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  '10165656': {'CampsiteID': '10165660',
#   'FacilityID': '10165656',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-09'},
#  '10165661': {'CampsiteID': '10165665',
#   'FacilityID': '10165661',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-03-23'},
#  '10165666': {'CampsiteID': '10165670',
#   'FacilityID': '10165666',
#   'CampsiteName': 'ScanPay 4',
#   'CampsiteType': 'MANAGEMENT',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Scan and Pay',
#   'CampsiteAccessible': False,
#   'CampsiteLongitude': 0,
#   'CampsiteLatitude': 0,
#   'CreatedDate': '2021-12-29',
#   'LastUpdatedDate': '2022-05-20'},
#  ...}

# %%
df = pd.DataFrame(data["RECDATA"])

df
# Out:
#        CampsiteID FacilityID             CampsiteName          CampsiteType  \
# 0               1     232446                      065        RV NONELECTRIC
# 1              10     232446                      075        RV NONELECTRIC
# 2             100     232447                      044  STANDARD NONELECTRIC
# 3            1000     232451                      078  STANDARD NONELECTRIC
# 4           10000     232709                      009           RV ELECTRIC
# ...           ...        ...                      ...                   ...
# 118648  999990060     256367          Masse Homestead               HIKE TO
# 118649  999990061     251865             Presque Isle  STANDARD NONELECTRIC
# 118650  999990062     251865     Outer Primitive Zone                  Zone
# 118651  999990063     251865       Oak Primitive Zone                  Zone
# 118652  999990064     251865  Stockton Primitive Zone                  Zone
#
#         TypeOfUse                Loop  CampsiteAccessible  CampsiteLongitude  \
# 0       Overnight                  C                False        -119.683914
# 1       Overnight                  C                False        -119.684601
# 2       Overnight         Upper Pines               False        -119.565040
# 3       Overnight  Hodgdon Campground               False        -119.866541
# 4       Overnight     REYNOLDS CREEK                False         -97.264983
# ...           ...                 ...                 ...                ...
# 118648  Overnight     Masse Homestead               False           0.000000
# 118649  Overnight            Stockton               False           0.000000
# 118650  Overnight               Outer               False           0.000000
# 118651  Overnight                 Oak               False           0.000000
# 118652  Overnight            Stockton               False           0.000000
#
#         CampsiteLatitude CreatedDate LastUpdatedDate
# 0              37.550125  2014-05-02      2023-05-24
# 1              37.550136  2014-05-02      2022-06-29
# 2              37.737625  2014-05-02      2022-06-29
# 3              37.799589  2014-05-02      2022-06-29
# 4              31.586164  2014-05-02      2022-09-14
# ...                  ...         ...             ...
# 118648          0.000000  2018-04-04      2021-01-22
# 118649          0.000000  2018-04-04      2020-10-15
# 118650          0.000000  2018-04-04      2023-08-05
# 118651          0.000000  2018-04-04      2023-08-05
# 118652          0.000000  2018-04-04      2023-08-05
#
# [118653 rows x 11 columns]

# %%
uf = df['FacilityID'].value_counts()
uf
# Out:
# 258830    360
# 232490    357
# 233627    328
# 233700    327
# 247661    322
#          ...
# 232359      1
# 234303      1
# 233962      1
# 234170      1
# 233933      1
# Name: FacilityID, Length: 4323, dtype: int64

# %%
unique_df = df.drop_duplicates(subset='FacilityID')
unique_df
# Out:
#        CampsiteID FacilityID       CampsiteName               CampsiteType  \
# 0               1     232446                065             RV NONELECTRIC
# 2             100     232447                044       STANDARD NONELECTRIC
# 3            1000     232451                078       STANDARD NONELECTRIC
# 4           10000     232709                009                RV ELECTRIC
# 5          100000     251938                032       STANDARD NONELECTRIC
# ...           ...        ...                ...                        ...
# 118465      99885     251950                003          STANDARD ELECTRIC
# 118511      99926     251975      Freighterview                    WALK TO
# 118521      99935     252282      Guard Station             CABIN ELECTRIC
# 118524      99938     251960  Riverview Shelter     GROUP SHELTER ELECTRIC
# 118531      99945     251941       Group Site A  GROUP SHELTER NONELECTRIC
#
#         TypeOfUse                                               Loop  \
# 0       Overnight                                                 C
# 2       Overnight                                        Upper Pines
# 3       Overnight                                 Hodgdon Campground
# 4       Overnight                                    REYNOLDS CREEK
# 5       Overnight                            THUNDER ROCK CAMPGROUND
# ...           ...                                                ...
# 118465  Overnight                                            Walleye
# 118511  Overnight             FREIGHTERVIEW CAMPSITE on GRAND ISLAND
# 118521  Overnight                        CRESCENT LAKE GUARD STATION
# 118524        Day  Shenango Lake Mahaney Outflow Riverview Picnic...
# 118531  Overnight                            Sand Island Group Sites
#
#         CampsiteAccessible  CampsiteLongitude  CampsiteLatitude CreatedDate  \
# 0                    False        -119.683914         37.550125  2014-05-02
# 2                    False        -119.565040         37.737625  2014-05-02
# 3                    False        -119.866541         37.799589  2014-05-02
# 4                    False         -97.264983         31.586164  2014-05-02
# 5                    False         -84.485965         35.076028  2016-12-08
# ...                    ...                ...               ...         ...
# 118465               False        -101.263095         47.617408  2016-12-08
# 118511               False         -86.652933         46.556736  2016-12-08
# 118521               False        -121.970000         43.501111  2016-12-08
# 118524               False         -80.465753         41.265766  2016-12-08
# 118531               False           0.000000          0.000000  2016-12-08
#
#        LastUpdatedDate
# 0           2023-05-24
# 2           2022-06-29
# 3           2022-06-29
# 4           2022-09-14
# 5           2022-06-29
# ...                ...
# 118465      2022-06-29
# 118511      2022-06-29
# 118521      2022-06-29
# 118524      2022-06-29
# 118531      2022-06-29
#
# [4323 rows x 11 columns]

# %%
new_df = unique_df[['FacilityID', 'CampsiteType', 'TypeOfUse', 'Loop', 'CampsiteAccessible', 'CampsiteLongitude', 'CampsiteLatitude', 'LastUpdatedDate']]
new_df
# Out:
#        FacilityID               CampsiteType  TypeOfUse  \
# 0          232446             RV NONELECTRIC  Overnight
# 2          232447       STANDARD NONELECTRIC  Overnight
# 3          232451       STANDARD NONELECTRIC  Overnight
# 4          232709                RV ELECTRIC  Overnight
# 5          251938       STANDARD NONELECTRIC  Overnight
# ...           ...                        ...        ...
# 118465     251950          STANDARD ELECTRIC  Overnight
# 118511     251975                    WALK TO  Overnight
# 118521     252282             CABIN ELECTRIC  Overnight
# 118524     251960     GROUP SHELTER ELECTRIC        Day
# 118531     251941  GROUP SHELTER NONELECTRIC  Overnight
#
#                                                      Loop  CampsiteAccessible  \
# 0                                                      C                False
# 2                                             Upper Pines               False
# 3                                      Hodgdon Campground               False
# 4                                         REYNOLDS CREEK                False
# 5                                 THUNDER ROCK CAMPGROUND               False
# ...                                                   ...                 ...
# 118465                                            Walleye               False
# 118511             FREIGHTERVIEW CAMPSITE on GRAND ISLAND               False
# 118521                        CRESCENT LAKE GUARD STATION               False
# 118524  Shenango Lake Mahaney Outflow Riverview Picnic...               False
# 118531                            Sand Island Group Sites               False
#
#         CampsiteLongitude  CampsiteLatitude LastUpdatedDate
# 0             -119.683914         37.550125      2023-05-24
# 2             -119.565040         37.737625      2022-06-29
# 3             -119.866541         37.799589      2022-06-29
# 4              -97.264983         31.586164      2022-09-14
# 5              -84.485965         35.076028      2022-06-29
# ...                   ...               ...             ...
# 118465        -101.263095         47.617408      2022-06-29
# 118511         -86.652933         46.556736      2022-06-29
# 118521        -121.970000         43.501111      2022-06-29
# 118524         -80.465753         41.265766      2022-06-29
# 118531           0.000000          0.000000      2022-06-29
#
# [4323 rows x 8 columns]

# %%
#new_df.to_json('reduced_data.json', orient='records')

# %%
unique2 = new_df["CampsiteType"].unique()
unique2
# Out:
# array(['RV NONELECTRIC', 'STANDARD NONELECTRIC', 'RV ELECTRIC',
#        'SHELTER NONELECTRIC', 'GROUP TENT ONLY AREA NONELECTRIC',
#        'STANDARD ELECTRIC', 'TENT ONLY NONELECTRIC',
#        'GROUP SHELTER ELECTRIC', 'CABIN NONELECTRIC',
#        'GROUP SHELTER NONELECTRIC', 'CABIN ELECTRIC', 'YURT',
#        'MANAGEMENT', 'GROUP STANDARD ELECTRIC',
#        'GROUP RV AREA NONELECTRIC', 'GROUP STANDARD NONELECTRIC',
#        'BOAT IN', 'GROUP STANDARD AREA NONELECTRIC', 'SHELTER ELECTRIC',
#        'LOOKOUT', 'WALK TO', 'PICNIC', 'EQUESTRIAN NONELECTRIC',
#        'HIKE TO', 'YES', 'GROUP PICNIC AREA',
#        'OVERNIGHT SHELTER NONELECTRIC', 'PARKING', 'EQUESTRIAN ELECTRIC',
#        'GROUP STANDARD AREA ELECTRIC', 'OVERNIGHT SHELTER ELECTRIC',
#        'TENT ONLY ELECTRIC', 'GROUP WALK TO', 'GROUP EQUESTRIAN',
#        'ANCHORAGE', 'MOORING', 'BALL FIELD'], dtype=object)

# %%
new_name = {'RV NONELECTRIC': 'RV',
            'STANDARD NONELECTRIC': '', 
            'RV ELECTRIC': 'RV',
            'SHELTER NONELECTRIC': 'Shelter', 
            'GROUP TENT ONLY AREA NONELECTRIC': 'Tent',
            'STANDARD ELECTRIC': '', 
            'TENT ONLY NONELECTRIC': 'Tent',
       'GROUP SHELTER ELECTRIC': 'Shelter', 
       'CABIN NONELECTRIC': 'Cabin',
       'GROUP SHELTER NONELECTRIC': 'Shelter', 
       'CABIN ELECTRIC': 'Cabin', 
       'YURT': 'Tent',
       'MANAGEMENT': '', 
       'GROUP STANDARD ELECTRIC': '',
       'GROUP RV AREA NONELECTRIC': 'RV', 
       'GROUP STANDARD NONELECTRIC':'',
       'BOAT IN': 'Water', 
       'GROUP STANDARD AREA NONELECTRIC': '', 
       'SHELTER ELECTRIC': 'Shelter',
       'LOOKOUT': 'View', 
       'WALK TO': 'Hike', 
       'PICNIC': 'Picnic', 
       'EQUESTRIAN NONELECTRIC': 'Horseback',
       'HIKE TO': 'Hike', 
       'YES': '',
       'GROUP PICNIC AREA': 'Picnic',
       'OVERNIGHT SHELTER NONELECTRIC': 'Shelter', 
       'PARKING': 'RV', 
       'EQUESTRIAN ELECTRIC':'Horseback',
       'GROUP STANDARD AREA ELECTRIC': '', 
       'OVERNIGHT SHELTER ELECTRIC': 'Shelter',
       'TENT ONLY ELECTRIC': 'Tent', 
       'GROUP WALK TO': 'Hike', 
       'GROUP EQUESTRIAN': 'Horseback',
       'ANCHORAGE': 'Water', 
       'MOORING': '',
        'BALL FIELD': 'Tent' }

# %%
# Clean up Employer category. Replace 'SELF' and 'SELF EMPLOYED' with 'SELF-EMPLOYED'
#df['Employer'] = df['Employer'].replace({'SELF': 'SELF-EMPLOYED', 'SELF EMPLOYED': 'SELF-EMPLOYED'})

new_df['CampsiteType'] = df['CampsiteType'].replace(new_name)
new_df
# Out:
# C:\Users\Jared\AppData\Local\Temp\ipykernel_34560\1334945341.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['CampsiteType'] = df['CampsiteType'].replace(new_name)
#        FacilityID CampsiteType  TypeOfUse  \
# 0          232446           RV  Overnight
# 2          232447               Overnight
# 3          232451               Overnight
# 4          232709           RV  Overnight
# 5          251938               Overnight
# ...           ...          ...        ...
# 118465     251950               Overnight
# 118511     251975         Hike  Overnight
# 118521     252282        Cabin  Overnight
# 118524     251960      Shelter        Day
# 118531     251941      Shelter  Overnight
#
#                                                      Loop  CampsiteAccessible  \
# 0                                                      C                False
# 2                                             Upper Pines               False
# 3                                      Hodgdon Campground               False
# 4                                         REYNOLDS CREEK                False
# 5                                 THUNDER ROCK CAMPGROUND               False
# ...                                                   ...                 ...
# 118465                                            Walleye               False
# 118511             FREIGHTERVIEW CAMPSITE on GRAND ISLAND               False
# 118521                        CRESCENT LAKE GUARD STATION               False
# 118524  Shenango Lake Mahaney Outflow Riverview Picnic...               False
# 118531                            Sand Island Group Sites               False
#
#         CampsiteLongitude  CampsiteLatitude LastUpdatedDate
# 0             -119.683914         37.550125      2023-05-24
# 2             -119.565040         37.737625      2022-06-29
# 3             -119.866541         37.799589      2022-06-29
# 4              -97.264983         31.586164      2022-09-14
# 5              -84.485965         35.076028      2022-06-29
# ...                   ...               ...             ...
# 118465        -101.263095         47.617408      2022-06-29
# 118511         -86.652933         46.556736      2022-06-29
# 118521        -121.970000         43.501111      2022-06-29
# 118524         -80.465753         41.265766      2022-06-29
# 118531           0.000000          0.000000      2022-06-29
#
# [4323 rows x 8 columns]

# %%
df = new_df[new_df['CampsiteType'].str.strip() != '']
df
# Out:
#        FacilityID CampsiteType  TypeOfUse  \
# 0          232446           RV  Overnight
# 4          232709           RV  Overnight
# 11         250877      Shelter  Overnight
# 91         252470         Tent  Overnight
# 222      10001451         Tent  Overnight
# ...           ...          ...        ...
# 118463     252971         Tent  Overnight
# 118511     251975         Hike  Overnight
# 118521     252282        Cabin  Overnight
# 118524     251960      Shelter        Day
# 118531     251941      Shelter  Overnight
#
#                                                      Loop  CampsiteAccessible  \
# 0                                                      C                False
# 4                                         REYNOLDS CREEK                False
# 11                                          Standard Site               False
# 91                                 Dundo Group Campground               False
# 222                                             Main Loop               False
# ...                                                   ...                 ...
# 118463                            Paw Paw Tunnel Campsite               False
# 118511             FREIGHTERVIEW CAMPSITE on GRAND ISLAND               False
# 118521                        CRESCENT LAKE GUARD STATION               False
# 118524  Shenango Lake Mahaney Outflow Riverview Picnic...               False
# 118531                            Sand Island Group Sites               False
#
#         CampsiteLongitude  CampsiteLatitude LastUpdatedDate
# 0             -119.683914         37.550125      2023-05-24
# 4              -97.264983         31.586164      2022-09-14
# 11            -115.384760         36.130110      2020-10-15
# 91             -78.717593         38.235217      2022-06-29
# 222            -93.345717         36.040823      2021-04-24
# ...                   ...               ...             ...
# 118463         -78.461452         39.544791      2022-06-29
# 118511         -86.652933         46.556736      2022-06-29
# 118521        -121.970000         43.501111      2022-06-29
# 118524         -80.465753         41.265766      2022-06-29
# 118531           0.000000          0.000000      2022-06-29
#
# [1661 rows x 8 columns]

# %%
df.to_json('final_data.json', orient='records')

# %%
df.to_csv('csv_data.csv', index = False)
