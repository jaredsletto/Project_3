# %%
import json
import pandas as pd

data = json.load(open('data.json', encoding = 'cp850'))

# %%
no_dup = set()
region_keys = {}
nw = []
ne = []
sw = []
se = []



for objects in data['RECDATA']:
    del objects['CampsiteID']
    del objects['CampsiteName']
    del objects['CreatedDate']
    if objects['FacilityID'] not in no_dup:
        no_dup.add(objects['FacilityID']);
    else:
        objects['FacilityID'] = 'NA'
    if (objects['CampsiteType'] == 'RV NONELECTRIC')|\
    (objects['CampsiteType'] == 'RV ELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP RV AREA NONELECTRIC')|\
    (objects['CampsiteType'] == 'PARKING'):
            objects['CampsiteType'] = "RV";
    if (objects['CampsiteType'] == 'SHELTER NONELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP SHELTER ELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP SHELTER NONELECTRIC')|\
    (objects['CampsiteType'] == 'OVERNIGHT SHELTER NONELECTRIC')|\
    (objects['CampsiteType'] == 'OVERNIGHT SHELTER ELECTRIC')|\
    (objects['CampsiteType'] == 'SHELTER ELECTRIC'):
            objects['CampsiteType'] = "Shelter";
    if (objects['CampsiteType'] == 'GROUP TENT ONLY AREA NONELECTRIC')|\
    (objects['CampsiteType'] == 'TENT ONLY NONELECTRIC')|\
    (objects['CampsiteType'] == 'YURT')|\
    (objects['CampsiteType'] == 'TENT ONLY ELECTRIC')|\
    (objects['CampsiteType'] == 'OVERNIGHT SHELTER ELECTRIC')|\
    (objects['CampsiteType'] == 'BALL FIELD'):
            objects['CampsiteType'] = "Tent";
    if (objects['CampsiteType'] == 'CABIN NONELECTRIC')|\
    (objects['CampsiteType'] == 'CABIN ELECTRIC'):
            objects['CampsiteType'] = "Cabin";
    if (objects['CampsiteType'] == 'BOAT IN')|\
    (objects['CampsiteType'] == 'ANCHORAGE'):
            objects['CampsiteType'] = "Water";
    if (objects['CampsiteType'] == 'LOOKOUT'):
            objects['CampsiteType'] = "View";
    if (objects['CampsiteType'] == 'WALK TO')|\
    (objects['CampsiteType'] == 'GROUP WALK TO')|\
    (objects['CampsiteType'] == 'HIKE TO'):
            objects['CampsiteType'] = "Hike";
    if (objects['CampsiteType'] == 'PICNIC')|\
    (objects['CampsiteType'] == 'GROUP WALK TO'):
            objects['CampsiteType'] = "Picnic";
    if (objects['CampsiteType'] == 'EQUESTRIAN NONELECTRIC')|\
    (objects['CampsiteType'] == 'EQUESTRIAN ELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP EQUESTRIAN'):
        objects['CampsiteType'] = "Horseback";
    if (objects['CampsiteType'] == 'STANDARD NONELECTRIC') |\
    (objects['CampsiteType'] == 'STANDARD ELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP STANDARD ELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP STANDARD NONELECTRIC')|\
    (objects['CampsiteType'] == 'GROUP STANDARD AREA NONELECTRIC')|\
    (objects['CampsiteType'] == 'YES')|\
    (objects['CampsiteType'] == 'GROUP STANDARD AREA ELECTRIC')|\
    (objects['CampsiteType'] == 'MOORING')|\
    (objects['CampsiteType'] == 'MANAGEMENT'):
            objects['FacilityID'] = 'NA';
    if objects['CampsiteLatitude'] > 39.50 and objects['CampsiteLongitude'] < -98.35:
        objects['Region'] = 'north_west';
    elif objects['CampsiteLatitude'] > 39.50 and objects['CampsiteLongitude'] > -98.35:
        objects['Region'] = 'north_east';
    elif objects['CampsiteLatitude'] < 39.50 and objects['CampsiteLongitude'] < -98.35:
        objects['Region'] = 'south_west';
    elif objects['CampsiteLatitude'] < 39.50 and objects['CampsiteLongitude'] > -98.35:
        objects['Region'] = 'south_east';
    if objects['FacilityID'] == 'NA':
        objects['CampsiteType'] = 'NA'
        objects['TypeOfUse'] = 'NA'
        objects['Loop'] = 'NA'
        objects['CampsiteAccessible'] = 'NA'
        objects['CampsiteLongitude'] = 'NA'
        objects['CampsiteLatitude'] = 'NA'
        objects['LastUpdatedDate'] = 'NA'
        objects['Region'] = 'NA';
    objects['Location'] = [objects['CampsiteLatitude'], objects['CampsiteLongitude']]
    del objects['CampsiteLatitude']
    del objects['CampsiteLongitude']
#     fac_id = objects['FacilityID']
#     del objects['FacilityID']
#     final_dict[fac_id] = objects
    if objects['Region'] == 'north_west':
        nw.append(objects)
    if objects['Region'] == 'north_east':
        ne.append(objects)
    if objects['Region'] == 'south_west':
        sw.append(objects)
    if objects['Region'] == 'south_east':
        se.append(objects)

# %%
nw
# Out:
# [{'FacilityID': '261696',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-11',
#   'Region': 'north_west',
#   'Location': [46.993093, -111.990061]},
#  {'FacilityID': '264411',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-30',
#   'Region': 'north_west',
#   'Location': [43.312133, -109.858197]},
#  {'FacilityID': '273785',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-09-16',
#   'Region': 'north_west',
#   'Location': [47.267952, -116.081203]},
#  {'FacilityID': '273308',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Picnic Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-26',
#   'Region': 'north_west',
#   'Location': [43.9039, -123.56927]},
#  {'FacilityID': '261822',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [46.739591, -111.888228]},
#  {'FacilityID': '10006208',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-12',
#   'Region': 'north_west',
#   'Location': [60.34805, -154.04274]},
#  {'FacilityID': '233596',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Group',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_west',
#   'Location': [48.178913, -116.892201]},
#  {'FacilityID': '233600',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Group',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_west',
#   'Location': [48.159246, -116.775395]},
#  {'FacilityID': '233637',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Group',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-04',
#   'Region': 'north_west',
#   'Location': [48.236785, -116.586491]},
#  {'FacilityID': '10007160',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [47.8420733512787, -116.196980915198]},
#  {'FacilityID': '253491',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRANITE BUTTE LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.8630166667, -112.464766667]},
#  {'FacilityID': '10009517',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'Box Canyon',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [41.09444384167, -105.222866246088]},
#  {'FacilityID': '252037',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SARDINE PEAK LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.5402138888999, -120.187855556]},
#  {'FacilityID': '236938',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [43.8468610442133, -121.866167720728]},
#  {'FacilityID': '237056',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [43.84448239644, -121.848567788734]},
#  {'FacilityID': '236991',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [43.8380112839932, -121.890479330305]},
#  {'FacilityID': '10038994',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [48.5559797046963, -116.939492302982]},
#  {'FacilityID': '233263',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cedar',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-01-20',
#   'Region': 'north_west',
#   'Location': [48.5482570000001, -116.87533]},
#  {'FacilityID': '233264',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'West Shores',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-01-20',
#   'Region': 'north_west',
#   'Location': [48.5655390000001, -116.904167]},
#  {'FacilityID': '10040565',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'N/A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [47.0863936, -112.603544]},
#  {'FacilityID': '10040589',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'N/A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [46.7924494816551, -112.584123229526]},
#  {'FacilityID': '273309',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Front Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-11',
#   'Region': 'north_west',
#   'Location': [43.98579979, -123.6622102]},
#  {'FacilityID': '10075403',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-12',
#   'Region': 'north_west',
#   'Location': [59.8797541320001, -139.774634194]},
#  {'FacilityID': '259309',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Walk-in',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-04',
#   'Region': 'north_west',
#   'Location': [44.281152, -110.627642]},
#  {'FacilityID': '234629',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CHIEF COVE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [57.70794, -153.9021]},
#  {'FacilityID': '10094038',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pink House Day Use Pavilions',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-25',
#   'Region': 'north_west',
#   'Location': [46.502222, -116.348055]},
#  {'FacilityID': '234120',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HRWD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-01-27',
#   'Region': 'north_west',
#   'Location': [41.9006403037573, -100.301308570193]},
#  {'FacilityID': '258831',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [43.9054585613076, -110.643038072703]},
#  {'FacilityID': '247664',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Jenny Lake',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-21',
#   'Region': 'north_west',
#   'Location': [43.75425914, -110.7213268]},
#  {'FacilityID': '247785',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main Road',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-18',
#   'Region': 'north_west',
#   'Location': [44.0055802815, -110.687973935]},
#  {'FacilityID': '10099575',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tent Village',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.9046046114165, -110.635694576848]},
#  {'FacilityID': '10101324',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Stehekin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-12',
#   'Region': 'north_west',
#   'Location': [48.348504115, -120.714055204]},
#  {'FacilityID': '10101333',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Stehekin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-22',
#   'Region': 'north_west',
#   'Location': [48.307874111, -120.654415224]},
#  {'FacilityID': '10101344',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Stehekin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-22',
#   'Region': 'north_west',
#   'Location': [48.313304111, -120.657925222]},
#  {'FacilityID': '10101398',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Picnic Vista',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-27',
#   'Region': 'north_west',
#   'Location': [47.143821, -121.933261]},
#  {'FacilityID': '10103111',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Meadow Peak Lookout',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-03',
#   'Region': 'north_west',
#   'Location': [48.0796557753607, -114.989084475588]},
#  {'FacilityID': '258832',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '100s',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-23',
#   'Region': 'north_west',
#   'Location': [44.105138, -110.667814]},
#  {'FacilityID': '255136',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Craters of the Moon Group Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.4726278210001, -113.566977519]},
#  {'FacilityID': '275085',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': '1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [48.297060507, -118.145918974]},
#  {'FacilityID': '234062',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Middle Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [47.909963879, -118.302986738]},
#  {'FacilityID': '10132083',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Steliko Lookout',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-08',
#   'Region': 'north_west',
#   'Location': [47.7403449999999, -120.344191]},
#  {'FacilityID': '10132085',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tyee Lookout',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-23',
#   'Region': 'north_west',
#   'Location': [47.8641220000001, -120.471649]},
#  {'FacilityID': '232868',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Hike To',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-22',
#   'Region': 'north_west',
#   'Location': [45.1136970390615, -121.769131732727]},
#  {'FacilityID': '255205',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tent Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [44.3246127734066, -123.490699110451]},
#  {'FacilityID': '15045',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-02-01',
#   'Region': 'north_west',
#   'Location': [43.961886, -111.853544]},
#  {'FacilityID': '10156120',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Area Lost Horse Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'north_west',
#   'Location': [46.7600653375268, -112.438188762618]},
#  {'FacilityID': '10158808',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'One',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-15',
#   'Region': 'north_west',
#   'Location': [40.181967, -109.693572]},
#  {'FacilityID': '260552',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.3792628240001, -105.852556879]},
#  {'FacilityID': '10163081',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-01-25',
#   'Region': 'north_west',
#   'Location': [43.18282, -111.1558]},
#  {'FacilityID': '250043',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Paddy Flat Guard Station',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-01-20',
#   'Region': 'north_west',
#   'Location': [44.774721, -115.950508]},
#  {'FacilityID': '262754',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Camp',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-02',
#   'Region': 'north_west',
#   'Location': [45.04343312, -122.4891093]},
#  {'FacilityID': '262756',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Camp',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-02',
#   'Region': 'north_west',
#   'Location': [45.03372815, -122.4855831]},
#  {'FacilityID': '10192010',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-26',
#   'Region': 'north_west',
#   'Location': [45.069868, -111.312247]},
#  {'FacilityID': '262752',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HEBO LAKE CAMPGROUND',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.2303788817487, -123.794785416325]},
#  {'FacilityID': '266137',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.73646329095, -121.617604618232]},
#  {'FacilityID': '234060',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-21',
#   'Region': 'north_west',
#   'Location': [48.6715966530001, -121.263675013]},
#  {'FacilityID': '266143',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'ROBIE CREEK PARK GROUP SHELTER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.630274, -115.997789]},
#  {'FacilityID': '267071',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Front',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-27',
#   'Region': 'north_west',
#   'Location': [44.10291, -121.624488]},
#  {'FacilityID': '267078',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.4812787738526, -121.638261377194]},
#  {'FacilityID': '259031',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-02',
#   'Region': 'north_west',
#   'Location': [46.902433753, -121.639429585]},
#  {'FacilityID': '267072',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.824095, -121.800764]},
#  {'FacilityID': '267552',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.4415300432671, -121.63519291151]},
#  {'FacilityID': '267554',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.112203131691, -121.62443729672]},
#  {'FacilityID': '269838',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HEYBROOK LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-29',
#   'Region': 'north_west',
#   'Location': [47.8083972, -121.5352]},
#  {'FacilityID': '272098',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RED IVES CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.0565889, -115.3515278]},
#  {'FacilityID': '272173',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STRAWBERRY CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.4755556, -111.9152778]},
#  {'FacilityID': '272243',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SHEEP CAMP PRIMITIVE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-11',
#   'Region': 'north_west',
#   'Location': [40.5999838930001, -122.593911419]},
#  {'FacilityID': '272248',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PELTIER BRIDGE PRIMITIVE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-23',
#   'Region': 'north_west',
#   'Location': [40.586262897, -122.551661867]},
#  {'FacilityID': '272250',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BRANDY CREEK PRIMITIVE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_west',
#   'Location': [40.6014110020001, -122.582691664]},
#  {'FacilityID': '272247',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRYSTAL CREEK PRIMITIVE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-11',
#   'Region': 'north_west',
#   'Location': [40.641736655, -122.671355944]},
#  {'FacilityID': '273378',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HIRZ CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.8740917, -122.2356194]},
#  {'FacilityID': '250031',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Equestrian Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.1804, -122.452577]},
#  {'FacilityID': '273868',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'ELK CREEK PAVILION (CLEARWATER NF)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.7919444, -116.1730556]},
#  {'FacilityID': '232323',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HUNT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.33765, -106.974166]},
#  {'FacilityID': '234509',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STOVE PRAIRIE ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.6838734000002, -105.39681541]},
#  {'FacilityID': '233833',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JACKS GULCH ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.6388090000001, -105.525323]},
#  {'FacilityID': '233927',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PINEY GUARD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.7572640000001, -106.560574]},
#  {'FacilityID': '232462',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'loop C',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.326528544, -105.593360682]},
#  {'FacilityID': '234164',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PICNIC POINT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.6526347360071, -115.671121134541]},
#  {'FacilityID': '233731',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STUB CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.793778, -105.904748]},
#  {'FacilityID': '233945',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JCGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-18',
#   'Region': 'north_west',
#   'Location': [41.2738720000001, -107.108653]},
#  {'FacilityID': '231840',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LKSD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.892672, -103.482777]},
#  {'FacilityID': '232011',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'PICB',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.925464, -114.850651]},
#  {'FacilityID': '233941',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WILLOW CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.142949, -105.953361]},
#  {'FacilityID': '234101',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'DOGWOOD DAY USE ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [40.6227030000001, -111.768129]},
#  {'FacilityID': '234454',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MUDDY GUARD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.159633, -106.912736]},
#  {'FacilityID': '233944',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JCCQ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [41.283039, -107.119993]},
#  {'FacilityID': '232469',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [58.6694562230001, -155.431234289]},
#  {'FacilityID': '234304',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BIMC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.333678, -111.553604]},
#  {'FacilityID': '233536',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LPAR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'north_west',
#   'Location': [45.727657, -120.651245]},
#  {'FacilityID': '234293',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRIZZLY RIDGE YURT ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.7430555556, -109.500833333]},
#  {'FacilityID': '231906',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HIDE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.914986, -109.648399]},
#  {'FacilityID': '234121',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'POWERHOUSE GROUP PICNIC AREA ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-03-21',
#   'Region': 'north_west',
#   'Location': [40.6926190000001, -115.476429]},
#  {'FacilityID': '234261',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STUMP CREEK GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.7941666667, -111.08]},
#  {'FacilityID': '234240',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SNOW SURVEY',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-17',
#   'Region': 'north_west',
#   'Location': [41.3265687947734, -106.378263873188]},
#  {'FacilityID': '234316',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COLGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.667493, -109.519068]},
#  {'FacilityID': '234606',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EAST',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.4661072037637, -109.621504095849]},
#  {'FacilityID': '232388',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'IRON',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.826648, -103.473541]},
#  {'FacilityID': '233996',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JARVIES BOAT IN GROUP ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.932541, -109.480777]},
#  {'FacilityID': '232465',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOOP A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-28',
#   'Region': 'north_west',
#   'Location': [46.735090879, -121.569064263]},
#  {'FacilityID': '234286',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'YELLOWJACKET GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.994461, -114.48251]},
#  {'FacilityID': '234246',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SEEDHOUSE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.7751590000001, -106.772612]},
#  {'FacilityID': '234252',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CARIBOU MOUNTAIN GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.149993, -111.319951]},
#  {'FacilityID': '234034',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BUCK PARK CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.782124, -116.741761]},
#  {'FacilityID': '233489',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Faranuf',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-21',
#   'Region': 'north_west',
#   'Location': [48.013693, -106.431149]},
#  {'FacilityID': '231845',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HIDD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [41.233658615, -105.434542697]},
#  {'FacilityID': '233961',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BEAVER CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-06',
#   'Region': 'north_west',
#   'Location': [43.9666201594943, -115.608769963577]},
#  {'FacilityID': '233881',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DEADWOOD LOOKOUT REC CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.1254030000002, -115.704062]},
#  {'FacilityID': '234251',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EGAN BASIN GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.053674, -111.570755]},
#  {'FacilityID': '234305',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WARC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.205729, -111.251225]},
#  {'FacilityID': '234266',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EIGHT MILE GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.532131, -111.575969]},
#  {'FacilityID': '232402',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STOL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.5858424777871, -115.677997182809]},
#  {'FacilityID': '234294',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LIMBER FLAG YURT ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.73441, -109.418788]},
#  {'FacilityID': '234315',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TRCGS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.752528, -109.682136]},
#  {'FacilityID': '231855',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WEST LAKE ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.791425, -105.564625]},
#  {'FacilityID': '232111',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FAMI',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.6321280000001, -115.369105]},
#  {'FacilityID': '234122',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'NAVAJO CLIFFS ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.9284139999999, -109.723986]},
#  {'FacilityID': '234611',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SUNLIGHT RANGER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.726998, -109.555018]},
#  {'FacilityID': '234303',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SQUIRREL MEADOWS CABIN (ID)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.0630300000001, -111.021982]},
#  {'FacilityID': '233962',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BARBER FLAT CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.8351850000003, -115.532575]},
#  {'FacilityID': '234268',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CUB RIVER GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.1389720000001, -111.673878]},
#  {'FacilityID': '233948',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BRUSH CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [41.341887, -106.524824]},
#  {'FacilityID': '232291',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'THIR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.3730940000003, -116.301819]},
#  {'FacilityID': '234273',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SUMMIT RIDGE LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.854345064, -104.052799057]},
#  {'FacilityID': '232076',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'NORT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.143646972046, -114.915635914176]},
#  {'FacilityID': '234198',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BOTTLE CREEK GROUP',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [41.193575, -106.882457]},
#  {'FacilityID': '234605',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-28',
#   'Region': 'north_west',
#   'Location': [42.764452, -112.088658]},
#  {'FacilityID': '232344',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SWIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.1723654919905, -116.12124731896]},
#  {'FacilityID': '232292',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BOIL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.3636950000002, -115.856659]},
#  {'FacilityID': '234084',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SANDSTONE CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-18',
#   'Region': 'north_west',
#   'Location': [41.1103230000001, -107.171081]},
#  {'FacilityID': '234317',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PAGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-29',
#   'Region': 'north_west',
#   'Location': [40.6663280000001, -109.916203]},
#  {'FacilityID': '233203',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SILVERTIP CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [47.925506, -113.285978]},
#  {'FacilityID': '233326',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TILLY JANE A-FRAME',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-03-23',
#   'Region': 'north_west',
#   'Location': [45.3988832683303, -121.646628037531]},
#  {'FacilityID': '232223',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TENT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.1199, -111.31066]},
#  {'FacilityID': '233921',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRIZZLY CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.8765204432827, -103.440998431366]},
#  {'FacilityID': '232400',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WARM',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.1366750000003, -115.323178]},
#  {'FacilityID': '118990',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BOW RIVER RANGER STATION',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-19',
#   'Region': 'north_west',
#   'Location': [41.52639, -106.38917]},
#  {'FacilityID': '118991',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SHEEP MOUNTAIN FIRE LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [44.1897222, -107.0044444]},
#  {'FacilityID': '119290',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Willaby',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [47.4623966215564, -123.857945593827]},
#  {'FacilityID': '233960',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRAHAM CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.9542084386578, -115.273097421242]},
#  {'FacilityID': '120890',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'POLK CAMP',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [55.3566758488038, -132.51833657303]},
#  {'FacilityID': '234134',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ATLANTA CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [43.8049892323399, -115.130370545528]},
#  {'FacilityID': '232309',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BIG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.628543037583, -115.436976735761]},
#  {'FacilityID': '233958',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DEER PARK CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.9154292141284, -115.401724597958]},
#  {'FacilityID': '232224',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LAKE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-11-09',
#   'Region': 'north_west',
#   'Location': [39.6073350730002, -106.044994556]},
#  {'FacilityID': '234260',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JOHNSON GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.718892, -111.20632]},
#  {'FacilityID': '232218',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RCLW',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-07-25',
#   'Region': 'north_west',
#   'Location': [43.7815331697021, -116.084726540424]},
#  {'FacilityID': '123390',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HIDDEN HORSE EQUESTRIAN CAMPGROUND',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_west',
#   'Location': [41.2196611, -122.9103139]},
#  {'FacilityID': '231857',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ECHO',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.6559894170001, -105.595060961]},
#  {'FacilityID': '234276',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CAPE HORN WINTER RENTAL ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.3686747559159, -115.12291425438]},
#  {'FacilityID': '234285',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CARTER MILITARY TRAIL YURT ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.791341, -109.759348]},
#  {'FacilityID': '233942',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LA PRELE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-28',
#   'Region': 'north_west',
#   'Location': [42.45852, -105.835242]},
#  {'FacilityID': '234263',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CLEAR CREEK GUARD STATION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.5263888889, -111.17]},
#  {'FacilityID': '234131',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CALPINE C.O.',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.678719, -120.463515999]},
#  {'FacilityID': '234296',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA MEDICINE POINT LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.8069170000001, -114.110162]},
#  {'FacilityID': '234309',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA TRAIL CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.569256, -110.835815]},
#  {'FacilityID': '233079',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BERG BAY CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.3644444444001, -132.004722222]},
#  {'FacilityID': '232945',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA EAGLE GLACIER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [58.5733333333, -134.749166667]},
#  {'FacilityID': '233016',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA WEST SWAN LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.6330388889, -149.8855]},
#  {'FacilityID': '233022',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CASCADE CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.9963888889, -132.783611111]},
#  {'FacilityID': '232970',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BEACH RIVER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.0186111111001, -147.380833333]},
#  {'FacilityID': '232939',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA PETERSON LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [58.4369444444001, -134.734444444]},
#  {'FacilityID': '232981',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SOFTUK BAR CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.2041666667001, -144.640555556]},
#  {'FacilityID': '233085',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA MALLARD SLOUGH CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.7102777778001, -132.541666667]},
#  {'FacilityID': '232941',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA DAN MOLLER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [58.2636111111001, -134.457777778]},
#  {'FacilityID': '233151',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MOOSE CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.525095, -112.25472]},
#  {'FacilityID': '232958',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA PLENTY CUTTHROAT CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [55.8260305556001, -131.451663889]},
#  {'FacilityID': '233002',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CASTLE FLATS CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.6461111111, -133.25]},
#  {'FacilityID': '233027',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SPURT COVE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [57.0363888889001, -132.878055556]},
#  {'FacilityID': '232921',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA HASSELBORG CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [57.6631305556, -134.254027778]},
#  {'FacilityID': '233067',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SHAKES SLOUGH 1 CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.7147222222, -132.105]},
#  {'FacilityID': '232924',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA LAKE ALEXANDER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [57.6700916667, -134.185205556]},
#  {'FacilityID': '234391',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA HORSE PRAIRIE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.0231420000001, -113.322829]},
#  {'FacilityID': '233025',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BEECHER PASS CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.5791666667, -133.069722222]},
#  {'FacilityID': '233026',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BARBER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_west',
#   'Location': [60.4374000000001, -149.9866]},
#  {'FacilityID': '233012',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SWAN LAKE CABIN PETERSBURG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [57.0305555556001, -132.691944444]},
#  {'FacilityID': '232972',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA MCKINLEY TRAIL CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.4436111111, -145.215833333]},
#  {'FacilityID': '232940',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA JOHN MUIR CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [58.4094444444001, -134.696666667]},
#  {'FacilityID': '233064',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA STANEY CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [55.8205555556001, -133.1525]},
#  {'FacilityID': '232991',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SHRODE LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.65639, -148.3108]},
#  {'FacilityID': '233000',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA UPPER PARADISE LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.3681277778001, -149.012516667]},
#  {'FacilityID': '233091',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA TANIS MESA NORTH CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [59.2483333333001, -138.502777778]},
#  {'FacilityID': '232967',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CHECATS LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [55.4872166667, -130.826977778]},
#  {'FacilityID': '234318',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA ANTONE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-08',
#   'Region': 'north_west',
#   'Location': [44.7809230000001, -112.210045]},
#  {'FacilityID': '232983',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SHELTER BAY CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.426, -146.663533333]},
#  {'FacilityID': '232965',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BAKEWELL LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [55.2605555556, -130.671111111]},
#  {'FacilityID': '233028',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CRESCENT SADDLE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.4453222222001, -149.505752778]},
#  {'FacilityID': '233023',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA FOX CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.7297833333001, -149.708822222]},
#  {'FacilityID': '234336',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BATTLE RIDGE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.874335, -110.89179]},
#  {'FacilityID': '232976',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA NELLIE MARTIN RIVER CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [59.9141666667001, -147.5]},
#  {'FacilityID': '234541',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA LOGANVILLE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.563916725, -120.661160963]},
#  {'FacilityID': '232901',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TROY',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.566348, -120.837649]},
#  {'FacilityID': '234365',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BASIN STATION CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.70959, -111.235502]},
#  {'FacilityID': '234506',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA MONTURE GUARD STATION CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-25',
#   'Region': 'north_west',
#   'Location': [47.1272760000001, -113.1523]},
#  {'FacilityID': '234415',
#   'CampsiteType': 'Cabin',
# ...
#   'Loop': 'AREA WINSTANLEY LAKE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [55.4277777778, -130.819444444]},
#  {'FacilityID': '233063',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SHIPLEY BAY CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.0922222222001, -133.501944444]},
#  {'FacilityID': '234321',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA NOTCH CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.882204, -112.137261]},
#  {'FacilityID': '233247',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Rooks Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.081387, -118.255644]},
#  {'FacilityID': '233293',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'West Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.496381, -109.952159]},
#  {'FacilityID': '233133',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TIMBER BUTTE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.92529, -122.571566]},
#  {'FacilityID': '233292',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'East Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.4603380000001, -109.668145]},
#  {'FacilityID': '233317',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Kenai National Wildlife Refuge',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.151206, -150.851357]},
#  {'FacilityID': '233132',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ADAMS RANGER STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.654746, -116.039551]},
#  {'FacilityID': '233249',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOOP A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.6662050000001, -118.700607]},
#  {'FacilityID': '234765',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'East Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.817994, -122.251526]},
#  {'FacilityID': '234771',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Diamond Creek Guard Station',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.7031583716363, -111.200391174518]},
#  {'FacilityID': '234745',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CABINS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.8403276656893, -109.914978804893]},
#  {'FacilityID': '233126',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WALDE LOOKOUT CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.2352777778, -115.635277778]},
#  {'FacilityID': '234632',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SWAN LAKE KITCHEN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [48.5184431861413, -118.836589499466]},
#  {'FacilityID': '250012',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MINTON PEAK LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.8280950000001, -115.770935]},
#  {'FacilityID': '234721',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cabin',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [57.900142, -135.157682]},
#  {'FacilityID': '234784',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ICICLE GROUP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.5855529564712, -120.807056555723]},
#  {'FacilityID': '233972',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KEYSTONE RANGER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [41.169832, -106.250588]},
#  {'FacilityID': '250036',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Green River',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.909318, -109.274755]},
#  {'FacilityID': '249996',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'CAVE POINT GROUP USE AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.64726137, -111.7023649]},
#  {'FacilityID': '250002',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.6566327, -111.7353996]},
#  {'FacilityID': '233153',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Eagleview Group Campground (Reservation)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.497764, -123.493048]},
#  {'FacilityID': '233157',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'TYEE PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.485437, -123.484921]},
#  {'FacilityID': '233155',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'MILLPOND PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.3828363484923, -122.942925189777]},
#  {'FacilityID': '233154',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lone Pine Group Campground (Reservation)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.390844, -122.939084]},
#  {'FacilityID': '233156',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'ROCK CREEK PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.397891, -122.929934]},
#  {'FacilityID': '234760',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.865006135803, -122.51196787021]},
#  {'FacilityID': '233128',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOOKOUT BUTTE LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.4895490000001, -115.875101]},
#  {'FacilityID': '233368',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.688247, -115.926542]},
#  {'FacilityID': '234729',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BIG LAKE WEST CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.375021, -121.881845]},
#  {'FacilityID': '234793',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FAIRVIEW RANGER STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [48.354444, -115.038295]},
#  {'FacilityID': '250041',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'POLE CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.1938888889001, -106.942222222]},
#  {'FacilityID': '233322',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ACKER ROCK LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-10',
#   'Region': 'north_west',
#   'Location': [43.052154, -122.646408]},
#  {'FacilityID': '233305',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Olallie Resort',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.8141440000001, -121.79029]},
#  {'FacilityID': '251161',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'South Unit',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.006968434, -103.505397292]},
#  {'FacilityID': '251354',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Axolotl Cabin',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.240672, -111.871457]},
#  {'FacilityID': '251454',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.2539884984824, -121.691036775175]},
#  {'FacilityID': '251435',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.7168077148235, -121.772250515208]},
#  {'FacilityID': '251365',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FALLS CREEK CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.4697396134719, -123.846966840747]},
#  {'FacilityID': '251434',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A Loop',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-09-24',
#   'Region': 'north_west',
#   'Location': [45.4980163903751, -121.816791013328]},
#  {'FacilityID': '251367',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'HYALITE PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.485355, -110.984462]},
#  {'FacilityID': '251352',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Henneberry House',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.076349, -112.790282]},
#  {'FacilityID': '251565',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BLACKSMITH FORK GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-08',
#   'Region': 'north_west',
#   'Location': [41.6591666667, -111.674444444]},
#  {'FacilityID': '251546',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Acorn Woman Peak Lookout',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-21',
#   'Region': 'north_west',
#   'Location': [42.0696833333001, -123.011877778]},
#  {'FacilityID': '251577',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ALLEN SPRINGS CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [44.5288110000001, -121.628373]},
#  {'FacilityID': '251710',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Owl Creek Packer Camp Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [47.439623, -113.609104]},
#  {'FacilityID': '251714',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SPENCER BENCH CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [60.7086145071842, -149.002804585542]},
#  {'FacilityID': '251712',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Equestrian Double Site',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.456257, -122.251241]},
#  {'FacilityID': '251711',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PAYSON LAKES GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.9247222222, -111.633055556]},
#  {'FacilityID': '251769',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Forest Road 034',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [42.8666666667001, -120.834444444]},
#  {'FacilityID': '234524',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Juniper Lake Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [40.4508402270001, -121.297056586]},
#  {'FacilityID': '251861',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Kenai Fjords National Park Cabins',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [59.8869122340001, -149.656165615]},
#  {'FacilityID': '251855',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CROCKER GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [39.8935333333001, -120.423683333]},
#  {'FacilityID': '251883',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.3193122116878, -122.096366434022]},
#  {'FacilityID': '251899',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COPPER BASIN GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-16',
#   'Region': 'north_west',
#   'Location': [43.8091666667, -113.843055556]},
#  {'FacilityID': '251905',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WHITETAIL YURT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [48.8277055555999, -115.814475]},
#  {'FacilityID': '251913',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'West Park #2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.925614, -119.307039]},
#  {'FacilityID': '251914',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Upper Parking Lot',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.929921, -119.272985]},
#  {'FacilityID': '251912',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SPILLWAY PARK - CHINOOK SHELTER (OR)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [45.932746, -119.302988]},
#  {'FacilityID': '253458',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rental Cabin',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [56.3950000000001, -132.647219444]},
#  {'FacilityID': '253500',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MILLER CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [46.6084166667001, -111.388855556]},
#  {'FacilityID': '253198',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ANNA CREEK CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [48.1685277778001, -113.790988889]},
#  {'FacilityID': '252282',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRESCENT LAKE GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_west',
#   'Location': [43.5011111110999, -121.97]}]

# %%
ne
# Out:
# [{'FacilityID': '10004657',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [41.958112, -70.074826]},
#  {'FacilityID': '10004659',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [41.847716, -69.948381]},
#  {'FacilityID': '10004661',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-10',
#   'Region': 'north_east',
#   'Location': [41.922798, -69.978996]},
#  {'FacilityID': '10004663',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_east',
#   'Location': [41.926892, -69.977201]},
#  {'FacilityID': '10004665',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_east',
#   'Location': [41.958068, -69.993971]},
#  {'FacilityID': '10004667',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [41.925892, -69.977154]},
#  {'FacilityID': '10005358',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.7566, -79.3937]},
#  {'FacilityID': '249981',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rainy Lake',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-13',
#   'Region': 'north_east',
#   'Location': [48.60219791, -93.10706452]},
#  {'FacilityID': '251969',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BERMUDA CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-14',
#   'Region': 'north_east',
#   'Location': [46.4711194444001, -86.6461638889]},
#  {'FacilityID': '252968',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Fifteen Mile Creek Campsite',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.623940035, -78.385331197]},
#  {'FacilityID': '251942',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BEAR LAKE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.5130174284114, -88.5283033628046]},
#  {'FacilityID': '251833',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group-Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-22',
#   'Region': 'north_east',
#   'Location': [44.3805780060001, -68.058301614]},
#  {'FacilityID': '251976',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DUCK LAKE CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-14',
#   'Region': 'north_east',
#   'Location': [46.4771194444, -86.6519027777999]},
#  {'FacilityID': '251974',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HEMLOCK CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4957638889001, -86.6822999999999]},
#  {'FacilityID': '233841',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'South',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-06-15',
#   'Region': 'north_east',
#   'Location': [47.7573254544162, -91.7846334965118]},
#  {'FacilityID': '10036879',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'north_east',
#   'Location': [39.55117, -88.62684]},
#  {'FacilityID': '10036909',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'north_east',
#   'Location': [39.53339, -88.6117]},
#  {'FacilityID': '251956',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shenango Lake Mahaney Spruce Cove Trails End Rolling Meadows Skyline Picnic Shelters',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.270553, -80.460491]},
#  {'FacilityID': '10040547',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-06-13',
#   'Region': 'north_east',
#   'Location': [43.048035, -72.947757]},
#  {'FacilityID': '10045243',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Highland Beach Suites',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [42.0449250720001, -70.072840216]},
#  {'FacilityID': '10045245',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Highland Beach Suites',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [42.0448718480001, -70.072767256]},
#  {'FacilityID': '10045247',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Highland Beach Suites',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-05-10',
#   'Region': 'north_east',
#   'Location': [42.0448168290001, -70.072689512]},
#  {'FacilityID': '10048970',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Barre Falls Picnic Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-10',
#   'Region': 'north_east',
#   'Location': [42.427326, -72.023392]},
#  {'FacilityID': '251946',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.480125, -79.441259]},
#  {'FacilityID': '234674',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group-Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'north_east',
#   'Location': [44.245278565, -68.309272376]},
#  {'FacilityID': '251973',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GULL POINT CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.5534305556001, -86.6968055556]},
#  {'FacilityID': '254086',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Turkey Creek Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.7224, -91.525202]},
#  {'FacilityID': '254085',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Sugar Bottom Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.759013, -91.557074]},
#  {'FacilityID': '254079',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Tailwater West Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.721837, -91.529734]},
#  {'FacilityID': '254081',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'East Overlook Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.724088, -91.527093]},
#  {'FacilityID': '10122722',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'East Branch',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_east',
#   'Location': [41.561053, -78.599103]},
#  {'FacilityID': '10132301',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Woodcock Creek Lake',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-06-11',
#   'Region': 'north_east',
#   'Location': [41.6910145, -80.0871999]},
#  {'FacilityID': '233165',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EAST BEARSKIN LAKE CAMPGROUND',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [48.0380977450841, -90.3946046668556]},
#  {'FacilityID': '255202',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Damsite and Spillway Recreation Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.716247, -79.504468]},
#  {'FacilityID': '10145539',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Katahdin Woods and Waters',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-23',
#   'Region': 'north_east',
#   'Location': [46.113810539, -68.797909978]},
#  {'FacilityID': '10149034',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-26',
#   'Region': 'north_east',
#   'Location': [40.6900694, -72.9900306]},
#  {'FacilityID': '10156151',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Chukar Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-20',
#   'Region': 'north_east',
#   'Location': [42, -49]},
#  {'FacilityID': '10158631',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Spillway',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-03-01',
#   'Region': 'north_east',
#   'Location': [39.796597, -79.356186]},
#  {'FacilityID': '255284',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Seven Points Picnic Shelters',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_east',
#   'Location': [40.379779, -78.077254]},
#  {'FacilityID': '255285',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Weaver Falls Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.242582, -78.231286]},
#  {'FacilityID': '255282',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Tatman Run Picnic Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.310544, -78.170995]},
#  {'FacilityID': '255281',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Aitch Picnic Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.376628, -78.162913]},
#  {'FacilityID': '10168556',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sailors Haven Cottage',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-28',
#   'Region': 'north_east',
#   'Location': [40.656666, -73.100277]},
#  {'FacilityID': '10174884',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Zone 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-26',
#   'Region': 'north_east',
#   'Location': [41.3264597670001, -74.769748894]},
#  {'FacilityID': '10177495',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Central Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-14',
#   'Region': 'north_east',
#   'Location': [41.701817, -86.947814]},
#  {'FacilityID': '10177496',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dunbar',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [41.682476, -87.001699]},
#  {'FacilityID': '264293',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DUCK HARBOR CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.028185, -68.653144]},
#  {'FacilityID': '10239229',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-04',
#   'Region': 'north_east',
#   'Location': [41.369715, -92.977561]},
#  {'FacilityID': '10239231',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-04',
#   'Region': 'north_east',
#   'Location': [41.367044, -92.980313]},
#  {'FacilityID': '10274250',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Lake View Recreation Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-27',
#   'Region': 'north_east',
#   'Location': [41.70853, -93.702414]},
#  {'FacilityID': '272094',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COTTONWOOD CAMPGROUND (IA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-15',
#   'Region': 'north_east',
#   'Location': [41.722371, -91.533962]},
#  {'FacilityID': '273344',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LAKE NINETEEN DISPERSED CAMPSITE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.1716666666667, -86.5441666666667]},
#  {'FacilityID': '273345',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'CLARK LAKE PAVILION',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.2420615031788, -89.3377168008086]},
#  {'FacilityID': '273778',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RUSSELL POND CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.0129311765814, -71.6515160472647]},
#  {'FacilityID': '273784',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Southern Loop',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.0773458039232, -88.7639602448342]},
#  {'FacilityID': '232174',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BASN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.267405, -71.021601]},
#  {'FacilityID': '233769',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GLEASONS LANDING/HURON',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.8707100000001, -85.920746]},
#  {'FacilityID': '233922',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SMITH RAPIDS PAVILION ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.9099280000001, -90.17412]},
#  {'FacilityID': '234237',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BLACK MOUNTAIN CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.19694, -71.172427]},
#  {'FacilityID': '234090',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'ELM BROOK',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [43.188993, -71.730626]},
#  {'FacilityID': '233548',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'MDAU',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.859403, -92.244088]},
#  {'FacilityID': '234238',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DOUBLEHEAD CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.167699, -71.130037]},
#  {'FacilityID': '234167',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOST LAKE CABINS ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.8777080741579, -88.5621663741838]},
#  {'FacilityID': '234235',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MCKEEVER CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.214948, -86.599907]},
#  {'FacilityID': '233897',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'ALUM CREEK',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.184846, -82.962574]},
#  {'FacilityID': '233676',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.161503, -72.8091]},
#  {'FacilityID': '233827',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CUT FOOT HORSE CAMPGROUND ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [47.560092022574, -94.1122896192579]},
#  {'FacilityID': '234142',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'NORTHFIELD BROOK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.685781, -73.090469]},
#  {'FacilityID': '233452',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BLUF',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.566121, -91.572262]},
#  {'FacilityID': '233905',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'DOE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-11-07',
#   'Region': 'north_east',
#   'Location': [39.618301, -83.211329]},
#  {'FacilityID': '234526',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BALS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.2309280823507, -89.3223418449143]},
#  {'FacilityID': '234119',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'DAY USE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.014671, -80.98844]},
#  {'FacilityID': '234176',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'EDWARD MACDOWELL',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [42.895592, -71.985984]},
#  {'FacilityID': '233588',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'POKEGAMA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [47.250064, -93.585513]},
#  {'FacilityID': '234734',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': "TOM'S LAKE CABIN",
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-01-07',
#   'Region': 'north_east',
#   'Location': [46.161544, -86.5905579999999]},
#  {'FacilityID': '233592',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'PR DAY USE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.669604, -94.111907]},
#  {'FacilityID': '233524',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'JOHN SPALDING REC AR ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.551269, -91.661726]},
#  {'FacilityID': '234411',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BUFFUMVILLE LAKE ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-08-28',
#   'Region': 'north_east',
#   'Location': [42.122022, -71.910594]},
#  {'FacilityID': '251549',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': "MINER'S RETREAT ENCLOSED SHELTER (IA)",
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-12-09',
#   'Region': 'north_east',
#   'Location': [41.378994, -93.029919]},
#  {'FacilityID': '251968',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': "ROAD'S END CAMPSITE on GRAND ISLAND",
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'north_east',
#   'Location': [46.497705, -86.644531]},
#  {'FacilityID': '233924',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SAILOR LAKE PAVILION ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.8464550000001, -90.268039]},
#  {'FacilityID': '233765',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PICNIC POINT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.3055420000001, -90.43561]},
#  {'FacilityID': '249984',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SURRY MOUNTAIN LAKE BEACH',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-08-29',
#   'Region': 'north_east',
#   'Location': [43.003592, -72.319041]},
#  {'FacilityID': '249980',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'OTTER BROOK LAKE BEACH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [42.964321, -72.232498]},
#  {'FacilityID': '234715',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Hudson',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.60013165, -74.054650048]},
#  {'FacilityID': '249983',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Stoughton Pond Rec Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.379319, -72.501499]},
#  {'FacilityID': '233140',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CASS LAKE LOOP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [47.3797520360105, -94.5285562213738]},
#  {'FacilityID': '234697',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SANDPIPER RECREATION AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.754086, -93.710792]},
#  {'FacilityID': '234658',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JUNIPER FLATS GROUP CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.485274, -86.6855619999999]},
#  {'FacilityID': '234698',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'OAK GROVE PICNIC AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.73858, -93.688252]},
#  {'FacilityID': '234687',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Day Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-24',
#   'Region': 'north_east',
#   'Location': [41.977913, -77.178832]},
#  {'FacilityID': '234694',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BOB SHETLER PICNIC AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.694798, -93.681318]},
#  {'FacilityID': '233212',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Ewing Point',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.2166856414405, -86.643716356637]},
#  {'FacilityID': '234689',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Day Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-24',
#   'Region': 'north_east',
#   'Location': [41.974681, -77.202587]},
#  {'FacilityID': '233321',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Adirondack Shelters',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.6771830760001, -77.4844425159999]},
#  {'FacilityID': '234678',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOOP A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.7015561320721, -85.6209689391661]},
#  {'FacilityID': '232456',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Bay Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.019314539, -86.103138369]},
#  {'FacilityID': '232457',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'D.H. DAY Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-30',
#   'Region': 'north_east',
#   'Location': [44.8918935560001, -86.0420554029999]},
#  {'FacilityID': '233309',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Wiley Post A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.596830201, -73.884493036]},
#  {'FacilityID': '233330',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Day',
#   'Loop': 'Ball Field',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.520463, -73.07492]},
#  {'FacilityID': '234681',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FARNSWORTH CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'north_east',
#   'Location': [41.7102777778001, -79.165]},
#  {'FacilityID': '250011',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'TOWNSHEND LAKE DAY USE AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.0594, -72.7055]},
#  {'FacilityID': '234690',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'LAMBS CREEK RECREATION AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.856484, -77.113907]},
#  {'FacilityID': '233367',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'CUYAHOGA ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-08-19',
#   'Region': 'north_east',
#   'Location': [41.2263779510001, -81.515159153]},
#  {'FacilityID': '234679',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SOUTH BRANCH TRAIL CAMP GROUP SITE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.484185725797, -83.793846610992]},
#  {'FacilityID': '233241',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Middle',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.640869358, -77.4499557139999]},
#  {'FacilityID': '233286',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WEST ASHTABULA CROSSING ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [47.161647, -98.007534]},
#  {'FacilityID': '233124',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'NORWAY BEACH PICNIC SHELTER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [47.3795375406141, -94.5219686131042]},
#  {'FacilityID': '234231',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shelters',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.35786, -83.072699]},
#  {'FacilityID': '234241',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RADEKE CABIN ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.996685, -71.366898]},
#  {'FacilityID': '233291',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'WEST HILL PARK ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [42.112352, -71.603856]},
#  {'FacilityID': '234790',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRAND ISLAND CABINS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.456123, -86.685936]},
#  {'FacilityID': '234699',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'COTTONWOOD RECREATION AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.690801, -93.674225]},
#  {'FacilityID': '234695',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'CHERRY GLEN PICNIC',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.734696, -93.680062]},
#  {'FacilityID': '234758',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Dolly Copp',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-07-20',
#   'Region': 'north_east',
#   'Location': [44.3257096506873, -71.2169502550676]},
#  {'FacilityID': '234655',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MURRAY BAY GROUP CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.4716530000001, -86.6552799999999]},
#  {'FacilityID': '234696',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'WALNUT RIDGE RECREATION AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-13',
#   'Region': 'north_east',
#   'Location': [41.731257, -93.712928]},
#  {'FacilityID': '233923',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SPEARHEAD POINT  ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [45.3269020000001, -90.4443669999999]},
#  {'FacilityID': '250818',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Dillon Lake Group Picnic Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.995143, -82.077067]},
#  {'FacilityID': '251044',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'NORTH HARTLAND LAKE BEACH (VT)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.602678, -72.366532]},
#  {'FacilityID': '251045',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'UNION VILLAGE DAM PICNIC AREA (VT)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [43.790322, -72.256756]},
#  {'FacilityID': '251120',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Dry Brooks Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [40.389906, -76.037538]},
#  {'FacilityID': '251265',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SOUTH OVERLOOK (IA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-05-26',
#   'Region': 'north_east',
#   'Location': [41.366046, -92.989069]},
#  {'FacilityID': '251275',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'FIFIELD (IA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.413336, -93.030703]},
#  {'FacilityID': '251366',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'North Overlook Picnic Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.376767, -92.970672]},
#  {'FacilityID': '251350',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Prairie View',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.951531, -83.752627]},
#  {'FacilityID': '251539',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'WHITEBREAST POINT SHELTER (IA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.393501, -93.040014]},
#  {'FacilityID': '251564',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Tully Lake Picnic Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [42.643846, -72.223041]},
#  {'FacilityID': '251620',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Channel Marker',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4538555556001, -86.6793388889]},
#  {'FacilityID': '251618',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LITTLE DUNE I CAMPSITE ON GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4772361111001, -86.6310555556]},
#  {'FacilityID': '251575',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Alosa Campsites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.0834124360001, -74.976328423]},
#  {'FacilityID': '251619',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Gamefence',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4973583333001, -86.6820833333]},
#  {'FacilityID': '251622',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LITTLE DUNE II CAMPSITE ON GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-14',
#   'Region': 'north_east',
#   'Location': [46.4773583333001, -86.6296638888999]},
#  {'FacilityID': '251621',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Shelter Ridge',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.5548472222001, -86.6632333333]},
#  {'FacilityID': '232508',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [44.3080089970001, -68.203743843]},
#  {'FacilityID': '251971',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DRIFTWOOD CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4862777778001, -86.6465055556]},
#  {'FacilityID': '251970',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HARDWOOD CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-07-14',
#   'Region': 'north_east',
#   'Location': [46.4909472222001, -86.6829861111]},
#  {'FacilityID': '251965',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PRESERVATION POINT CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.5562055556, -86.6927694444]},
#  {'FacilityID': '251967',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOON CALL CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4717388889, -86.6513999999999]},
#  {'FacilityID': '251955',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shenango Lake Shenango Lakeside Picnic Shelter',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.29529, -80.434699]},
#  {'FacilityID': '251957',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Clark Rec Area Day Use',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.284632, -80.427051]},
#  {'FacilityID': '251972',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LITTLE DUCK CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'north_east',
#   'Location': [46.4835, -86.6453805556]},
#  {'FacilityID': '252971',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Paw Paw Tunnel Campsite',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [39.5447912870001, -78.461452139]},
#  {'FacilityID': '251975',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FREIGHTERVIEW CAMPSITE on GRAND ISLAND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [46.5567361111001, -86.6529333333]},
#  {'FacilityID': '251960',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shenango Lake Mahaney Outflow Riverview Picnic Shelter',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'north_east',
#   'Location': [41.265766, -80.465753]}]

# %%
sw
# Out:
# [{'FacilityID': '232446',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-24',
#   'Region': 'south_west',
#   'Location': [37.550124511, -119.683913958]},
#  {'FacilityID': '250877',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Standard Site',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [36.13011, -115.38476]},
#  {'FacilityID': '10004152',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-06-29',
#   'Region': 'south_west',
#   'Location': [37.741599437, -119.60264025]},
#  {'FacilityID': '233392',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Point Supreme CG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-20',
#   'Region': 'south_west',
#   'Location': [37.610919246, -112.831477637]},
#  {'FacilityID': '10005253',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-03',
#   'Region': 'south_west',
#   'Location': [38.477314480004, -120.007484246871]},
#  {'FacilityID': '257007',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'n/a',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-28',
#   'Region': 'south_west',
#   'Location': [38.145151, -109.621006]},
#  {'FacilityID': '10029004',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [37.75055, -121.009551]},
#  {'FacilityID': '10029012',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-10',
#   'Region': 'south_west',
#   'Location': [37.784997, -120.805419]},
#  {'FacilityID': '252281',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Creek Pasture Group Site',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-13',
#   'Region': 'south_west',
#   'Location': [38.170228, -109.634189]},
#  {'FacilityID': '251958',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'south_west',
#   'Location': [38.990427336, -114.221805033]},
#  {'FacilityID': '10039887',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [39.4287982600001, -121.110083037]},
#  {'FacilityID': '10039993',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [39.4325334270001, -121.124268903]},
#  {'FacilityID': '10040022',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [39.4696527130001, -121.165553354]},
#  {'FacilityID': '10040591',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main Loop',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [38.91403, -107.03256]},
#  {'FacilityID': '10046933',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_west',
#   'Location': [35.5747788330389, -118.529896794025]},
#  {'FacilityID': '10048964',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Use Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-25',
#   'Region': 'south_west',
#   'Location': [36.0355584000001, -114.802880617]},
#  {'FacilityID': '10048998',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [37.81139873, -120.7136273]},
#  {'FacilityID': '10049273',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-22',
#   'Region': 'south_west',
#   'Location': [34.1376886410354, -108.481474267702]},
#  {'FacilityID': '10052227',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RV',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-15',
#   'Region': 'south_west',
#   'Location': [34.1371911645692, -108.488862226749]},
#  {'FacilityID': '10068512',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cottonwood Cove',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-09-22',
#   'Region': 'south_west',
#   'Location': [35.4943385500001, -114.687358367]},
#  {'FacilityID': '10077451',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dru Barner CG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-12',
#   'Region': 'south_west',
#   'Location': [38.9429327100001, -120.7639305]},
#  {'FacilityID': '10077501',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Panchuela',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-17',
#   'Region': 'south_west',
#   'Location': [35.8303553269061, -105.664160170918]},
#  {'FacilityID': '10085599',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-28',
#   'Region': 'south_west',
#   'Location': [37.377819, -113.643944]},
#  {'FacilityID': '10086109',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Upper Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-29',
#   'Region': 'south_west',
#   'Location': [36.949961, -113.793284]},
#  {'FacilityID': '10119505',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'H┼ìlua',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-27',
#   'Region': 'south_west',
#   'Location': [20.7397085150001, -156.218381527]},
#  {'FacilityID': '10122832',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sollers Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-06-21',
#   'Region': 'south_west',
#   'Location': [32.4080000000001, -110.707]},
#  {'FacilityID': '258825',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Desert View',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-04',
#   'Region': 'south_west',
#   'Location': [36.0399639230001, -111.822537613]},
#  {'FacilityID': '256932',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Big Meadow Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.719413, -118.825107]},
#  {'FacilityID': '232500',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SANTA BARBARA ISLAND AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.479368133, -119.028699478]},
#  {'FacilityID': '232502',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ANACAPA ISLAND AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.013854216, -119.367751495]},
#  {'FacilityID': '232499',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BACKCOUNTRY AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.010677516, -119.660805191]},
#  {'FacilityID': '232501',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SAN MIGUEL ISLAND AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.040470075, -120.348806222]},
#  {'FacilityID': '10215894',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower Tonto Creek',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-07',
#   'Region': 'south_west',
#   'Location': [34.332549, -111.097312]},
#  {'FacilityID': '247566',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PRIMITIVE-No water/electric/generators',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-01',
#   'Region': 'south_west',
#   'Location': [32.0720247360001, -112.728475827]},
#  {'FacilityID': '10220609',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HORSE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-11',
#   'Region': 'south_west',
#   'Location': [37.539277, -119.653589]},
#  {'FacilityID': '10220612',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cabin Row',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'south_west',
#   'Location': [39.040417, -120.12026]},
#  {'FacilityID': '270816',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RV Non-Generator',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-31',
#   'Region': 'south_west',
#   'Location': [31.9401895880001, -112.809759174]},
#  {'FacilityID': '232448',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A001-A075',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.874137606, -119.353922587]},
#  {'FacilityID': '272095',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [33.3349097628067, -110.829088282507]},
#  {'FacilityID': '272246',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tent',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.7456638943326, -119.783935164155]},
#  {'FacilityID': '234685',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [37.7452404850001, -105.506130942]},
#  {'FacilityID': '272300',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JUMBO ROCKS CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [33.9918520890001, -116.064881105]},
#  {'FacilityID': '231881',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SILV',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.146287867, -106.893106167]},
#  {'FacilityID': '234287',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MANZANITA ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.9360230000001, -111.745146]},
#  {'FacilityID': '231882',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SILV',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.1421140800001, -106.89591556]},
#  {'FacilityID': '231886',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COAL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.2346635940001, -107.702599222]},
#  {'FacilityID': '232163',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'PONDEROSA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-16',
#   'Region': 'south_west',
#   'Location': [36.2546820000001, -115.643479]},
#  {'FacilityID': '231914',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.6092090000001, -112.25991]},
#  {'FacilityID': '233812',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LAKE ISABEL CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.981031, -105.047423]},
#  {'FacilityID': '233440',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BRID',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.122204, -119.875349]},
#  {'FacilityID': '233808',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ROBERTS CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.3462460000001, -105.92803]},
#  {'FacilityID': '234532',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JCGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.071119, -112.168004]},
#  {'FacilityID': '232186',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.3121870000001, -119.892458]},
#  {'FacilityID': '234470',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'EAST',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.2605724316803, -112.506715153263]},
#  {'FacilityID': '234515',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CALDWELL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-06-07',
#   'Region': 'south_west',
#   'Location': [33.746257, -109.369841]},
#  {'FacilityID': '231867',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CHAL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.7125086290001, -106.232707224]},
#  {'FacilityID': '232299',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'CRES',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-09-27',
#   'Region': 'south_west',
#   'Location': [34.8263099999999, -111.80632]},
#  {'FacilityID': '234460',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'CEDAR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.358906, -105.681674]},
#  {'FacilityID': '233888',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRESCENT MOON RANCH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.8253330000001, -111.802064]},
#  {'FacilityID': '234105',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ALVARADO',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.078895921, -105.567076841]},
#  {'FacilityID': '233868',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BASSAM CABIN ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.7459860000001, -105.939065]},
#  {'FacilityID': '234496',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.1755688150001, -106.377281236]},
#  {'FacilityID': '234495',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'CIENEGA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.169700124, -106.381825292]},
#  {'FacilityID': '234550',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'GROOM CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.470885777, -112.43481368]},
#  {'FacilityID': '234494',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BALSAM ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.2147016710002, -106.408062337]},
#  {'FacilityID': '232101',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LAKE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.9831432050001, -105.056128059]},
#  {'FacilityID': '232473',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Black Rock Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-20',
#   'Region': 'south_west',
#   'Location': [34.073442782, -116.389470442]},
#  {'FacilityID': '234588',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'EAST MAROON',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-06-06',
#   'Region': 'south_west',
#   'Location': [39.09831, -106.939802]},
#  {'FacilityID': '234129',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRESCENT MINING',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.989561, -106.413732]},
#  {'FacilityID': '234483',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CARNERO',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-15',
#   'Region': 'south_west',
#   'Location': [37.989612, -106.423469]},
#  {'FacilityID': '232195',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CUTT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.8746025920001, -109.417767981]},
#  {'FacilityID': '233932',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MINR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.0920621401743, -105.106853614982]},
#  {'FacilityID': '232470',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.999014926, -116.120746502]},
#  {'FacilityID': '233447',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CANA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.090494, -98.606848]},
#  {'FacilityID': '232471',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.743659167, -115.81484835]},
#  {'FacilityID': '234531',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'POGS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.485839611097, -112.300461502572]},
#  {'FacilityID': '233431',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'THUM',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.777008, -123.084644]},
#  {'FacilityID': '232489',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-13',
#   'Region': 'south_west',
#   'Location': [36.2108031810001, -112.059614246]},
#  {'FacilityID': '231922',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'TWIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.5495980000001, -111.722245]},
#  {'FacilityID': '234492',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'NINE MILE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.2144907070001, -106.422390217]},
#  {'FacilityID': '234528',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COWPUNCHER',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.979543, -111.656236]},
#  {'FacilityID': '232289',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LITT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.2750909941893, -111.588632808724]},
#  {'FacilityID': '232491',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'Day Use Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-09-07',
#   'Region': 'south_west',
#   'Location': [37.8270480570001, -122.491317768]},
#  {'FacilityID': '234077',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HORSETHIEF',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.1607599810001, -112.292124985]},
#  {'FacilityID': '234572',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AQRS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-06',
#   'Region': 'south_west',
#   'Location': [38.1952069999999, -111.576006]},
#  {'FacilityID': '234456',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KENDRICK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.4222253675252, -111.737858407794]},
#  {'FacilityID': '232297',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'JEME',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.8171850000001, -106.606744]},
#  {'FacilityID': '232159',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'G',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-02',
#   'Region': 'south_west',
#   'Location': [39.3105997730001, -106.640726327]},
#  {'FacilityID': '231876',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KELS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.305504377, -105.265619671]},
#  {'FacilityID': '232498',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.0491933430001, -119.562883011]},
#  {'FacilityID': '233724',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HORSESHOE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.2003702200001, -106.08633678]},
#  {'FacilityID': '232192',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BROO',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.8749727380001, -109.413965483]},
#  {'FacilityID': '232207',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'THUM',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.551885026, -112.519377302]},
#  {'FacilityID': '234783',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Holua Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-09',
#   'Region': 'south_west',
#   'Location': [20.7401102310001, -156.218716718]},
#  {'FacilityID': '233721',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SPILLWAY',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.9062383890001, -105.468716222]},
#  {'FacilityID': '234255',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ELWOOD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.403807, -106.638404]},
#  {'FacilityID': '118993',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LONE CONE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [37.89315, -108.1586194]},
#  {'FacilityID': '118992',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MATTERHORN CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_west',
#   'Location': [37.8436, -107.8823278]},
#  {'FacilityID': '234439',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SPVC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.357335, -111.956552]},
#  {'FacilityID': '118995',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'PINECREST DAY USE AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-06-02',
#   'Region': 'south_west',
#   'Location': [38.1920135282045, -119.993702533204]},
#  {'FacilityID': '233664',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'POMO',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.718528, -122.99994]},
#  {'FacilityID': '234487',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BREWERY CREEK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-15',
#   'Region': 'south_west',
#   'Location': [38.2873560000001, -106.167696]},
#  {'FacilityID': '232285',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SHOW',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-04',
#   'Region': 'south_west',
#   'Location': [32.4074820000001, -110.72018]},
#  {'FacilityID': '126690',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FRAIZER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-01-20',
#   'Region': 'south_west',
#   'Location': [33.6664275980001, -111.124081286]},
#  {'FacilityID': '234500',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'YUCA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [34.99787, -106.320394]},
#  {'FacilityID': '233887',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SYCAMORE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.3517360000001, -111.970057]},
#  {'FacilityID': '234459',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FERNOW',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.0087950000001, -111.862932]},
#  {'FacilityID': '234497',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'LAS HUERTAS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.2350228930001, -106.412906221]},
#  {'FacilityID': '232815',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA RANCHERIA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.2462970000001, -119.162992]},
#  {'FacilityID': '232136',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'G',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.0720954884777, -119.157134494345]},
#  {'FacilityID': '234106',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA FREMONT CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.5433321874087, -119.821722613722]},
#  {'FacilityID': '234323',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA LIVE OAK SOUTH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.7016117814413, -118.462489424069]},
#  {'FacilityID': '233732',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA JACKSON FLAT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-01',
#   'Region': 'south_west',
#   'Location': [34.3829890000001, -117.735237]},
#  {'FacilityID': '234600',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA PINE MOUNTAIN LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.3670080000001, -123.020471]},
#  {'FacilityID': '232020',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BLAC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.832478, -116.740025]},
#  {'FacilityID': '232031',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COUN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.1714630000001, -116.882544]},
#  {'FacilityID': '232349',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA ROBBS HUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.9247450000001, -120.403327]},
#  {'FacilityID': '232237',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BISH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.2444410000001, -118.593461]},
#  {'FacilityID': '232240',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TABL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.20807, -118.569925]},
#  {'FacilityID': '232239',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GWLK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.453933, -118.739092]},
#  {'FacilityID': '232302',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOON',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.002148, -120.31431]},
#  {'FacilityID': '232819',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.7982710000001, -118.451897]},
#  {'FacilityID': '232809',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.141522, -118.598523]},
#  {'FacilityID': '232812',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA COLLEGE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.252174072315, -119.169864849458]},
#  {'FacilityID': '233775',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA PINES GROUP/STANISLAUS',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.8216540000001, -120.083564]},
#  {'FacilityID': '232348',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA LOON LAKE CHALET',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.98, -120.32]},
#  {'FacilityID': '232910',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.327158, -119.579342]},
#  {'FacilityID': '231947',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'YARR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.6556889999999, -117.453458]},
#  {'FacilityID': '232823',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HOLEY MEADOW',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_west',
#   'Location': [35.9576259999999, -118.619254]},
#  {'FacilityID': '231961',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'UPPE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.5561430000001, -119.771318]},
#  {'FacilityID': '231952',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WOOD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [32.8549960000001, -116.41765]},
#  {'FacilityID': '231974',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TANG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [34.292964, -116.864057]},
#  {'FacilityID': '232782',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'YELL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.804969, -118.941789]},
#  {'FacilityID': '232054',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GREE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.2457164794894, -117.062038713444]},
#  {'FacilityID': '231950',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EL P',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [32.890275, -116.451414]},
#  {'FacilityID': '233952',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SHADY COVE GROUP CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.2072390000001, -117.043201]},
#  {'FacilityID': '231949',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRES',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.312586, -116.863587]},
#  {'FacilityID': '231966',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BOUL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.220169, -116.969221]},
#  {'FacilityID': '233104',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA VAN VLECK BUNKHOUSE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.936592, -120.321775]},
#  {'FacilityID': '234006',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA HARVEY WEST CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.751992, -120.269372]},
#  {'FacilityID': '234601',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA OAK FLAT LOOKOUT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.5352777778001, -118.706944444]},
#  {'FacilityID': '234458',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA BIG MEADOWS CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.7193090000001, -118.835211]},
#  {'FacilityID': '234457',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA CAMP FOUR AND HALF CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.8622222222, -119.288611111]},
#  {'FacilityID': '233701',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'CHOW',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.226908, -119.985263]},
#  {'FacilityID': '231954',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TENT',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.847077, -120.237278]},
#  {'FacilityID': '232107',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STUM',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.9036961326428, -120.593647192118]},
#  {'FacilityID': '231964',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BIG',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-02',
#   'Region': 'south_west',
#   'Location': [34.337368, -116.698869]},
#  {'FacilityID': '233188',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'MANITOU LAKE PAVILION',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-14',
#   'Region': 'south_west',
#   'Location': [39.088344, -105.098482]},
#  {'FacilityID': '233232',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'STONE CELLAR GUARD STATION',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-12-15',
#   'Region': 'south_west',
#   'Location': [38.0192064575621, -106.681427595243]},
#  {'FacilityID': '234710',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ALDER GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-13',
#   'Region': 'south_west',
#   'Location': [37.7044444444, -106.646666667]},
#  {'FacilityID': '234667',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SILESCA CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.332885, -108.12506]},
#  {'FacilityID': '233402',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KENT SPRINGS CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-12-16',
#   'Region': 'south_west',
#   'Location': [31.7181739999999, -110.873315]},
#  {'FacilityID': '233213',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MOOSE MANOR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.052677, -108.098629]},
#  {'FacilityID': '234058',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-07',
#   'Region': 'south_west',
#   'Location': [37.6384471970001, -112.167140427]},
#  {'FacilityID': '233216',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BLACK BEAR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.0522470000001, -108.09828]},
#  {'FacilityID': '233289',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JACKSON GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.213435, -107.523252]},
#  {'FacilityID': '233130',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LITTLE LASIER MEADOWS CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.4902079410001, -120.515164034]},
#  {'FacilityID': '234684',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DAVENPORT CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.055042191, -105.068950996]},
#  {'FacilityID': '233314',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Trimmer Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.905918, -119.289334]},
#  {'FacilityID': '234686',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SPRUCE GROVE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [39.1374067380002, -105.461301691]},
#  {'FacilityID': '234700',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.133668, -105.532909]},
#  {'FacilityID': '234683',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DAWSON CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.0054864285869, -106.353608495515]},
#  {'FacilityID': '234706',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PLATORO CABIN 2',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.3527777778, -106.528055556]},
#  {'FacilityID': '234664',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'ASPEN LEAF',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-10',
#   'Region': 'south_west',
#   'Location': [38.6470440000001, -108.677066]},
#  {'FacilityID': '234707',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PLATORO CABIN 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.3527777778, -106.528055556]},
#  {'FacilityID': '234660',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'UPPER CROSSING GUARD STATION',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-12-16',
#   'Region': 'south_west',
#   'Location': [38.13885, -106.456017]},
#  {'FacilityID': '247596',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'FITTON GUARD STATION CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-13',
#   'Region': 'south_west',
#   'Location': [37.487874, -106.468404]},
#  {'FacilityID': '234654',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SLY GUARD CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.710186, -120.593051]},
#  {'FacilityID': '233335',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-23',
#   'Region': 'south_west',
#   'Location': [37.5405936660001, -107.198578374]},
#  {'FacilityID': '233178',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SHAW HOUSE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [31.9263888889, -109.955555556]},
#  {'FacilityID': '233177',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HALF MOON RANCH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-25',
#   'Region': 'south_west',
#   'Location': [31.9463722222001, -109.955341667]},
#  {'FacilityID': '234224',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA POSO GUARD STATION CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-22',
#   'Region': 'south_west',
#   'Location': [35.8037850000001, -118.646405]},
#  {'FacilityID': '233219',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SABINO CANYON RECREATION AREA CACTUS RAMADA 2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [32.318967, -110.815906]},
#  {'FacilityID': '231971',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'IRON',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.3036760000001, -117.011623]},
#  {'FacilityID': '234135',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BEAC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.868099, -120.395838]},
#  {'FacilityID': '232264',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'MLS2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.2510249080001, -120.650444163]},
#  {'FacilityID': '232030',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'COON',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.149379, -116.710839]},
#  {'FacilityID': '234000',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA TENT PEG GROUP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.2636360000001, -117.082125]},
#  {'FacilityID': '234133',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA SILVER CREEK GROUP CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.8278865550451, -120.389217701868]},
#  {'FacilityID': '233933',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA QUAKING ASPEN CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.121815, -118.544509]},
#  {'FacilityID': '234324',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA WISHON CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-07',
#   'Region': 'south_west',
#   'Location': [36.1897746113974, -118.666250405389]},
#  {'FacilityID': '232049',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GERL',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.9755460000001, -120.393488]},
#  {'FacilityID': '232021',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GRP4',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.90251, -120.584323]},
#  {'FacilityID': '231951',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LUPI',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [32.8865559999999, -116.441439]},
#  {'FacilityID': '232422',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TRAI',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.966135, -119.271438]},
#  {'FacilityID': '232875',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA KASPIAN CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.1136270000001, -120.160047]},
#  {'FacilityID': '233168',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SEELY CREEK GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.312139, -111.429603]},
#  {'FacilityID': '234172',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CHIP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.5340776846497, -120.243462335737]},
#  {'FacilityID': '232827',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Yurt',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.1218550000001, -118.545202]},
#  {'FacilityID': '232890',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.9289669999999, -118.491071]},
#  {'FacilityID': '233167',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'INDIAN CREEK GUARD STATION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.1412740000001, -111.458294]},
#  {'FacilityID': '233117',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CERRO ALTO CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.4244370000001, -120.737059]},
#  {'FacilityID': '234719',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'DRIPPING SPRINGS CAMPGROUND (CA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [33.461547, -116.970972]},
#  {'FacilityID': '249982',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BUCKEYE FLAT ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.5225877400001, -118.7642207]},
#  {'FacilityID': '234680',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'APACHE MAID CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [34.7113300000001, -111.520452]},
#  {'FacilityID': '247595',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'OFF COW CAMP CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-13',
#   'Region': 'south_west',
#   'Location': [37.489583, -106.471472]},
#  {'FacilityID': '233220',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SABINO CANYON RECREATION AREA CACTUS RAMADA 1',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [32.3188070000001, -110.816536]},
#  {'FacilityID': '233382',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'CAPULIN SPRING PICNIC SITE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.2168264510001, -106.416215292]},
#  {'FacilityID': '234759',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'C',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [34.4655060540002, -112.445104914]},
#  {'FacilityID': '234761',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOST CLAIM',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [37.8218860000001, -120.049052]},
#  {'FacilityID': '234753',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Left Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.78807, -118.668184]},
#  {'FacilityID': '233883',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'INDE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.3786817760001, -105.10424902]},
#  {'FacilityID': '234713',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Pine Valley ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-03',
#   'Region': 'south_west',
#   'Location': [37.3780090000001, -113.475518]},
#  {'FacilityID': '234739',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.7766132178693, -119.896763056323]},
#  {'FacilityID': '250037',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dwelling',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [39.301468, -111.297291]},
#  {'FacilityID': '250027',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PORTAL CCC HOUSE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [31.9008333, -109.1608333]},
#  {'FacilityID': '233169',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KENTUCKY CAMP CABIN AND HEADQUARTERS BUILDING',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [31.7333333333, -110.716666667]},
#  {'FacilityID': '250033',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PALISADES RANGER RESIDENCE CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [32.410416512, -110.714698591]},
#  {'FacilityID': '250000',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Oak Shores Day Use Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-07-10',
#   'Region': 'south_west',
#   'Location': [38.558537, -122.233298]},
#  {'FacilityID': '233325',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GROUSE VALLEY',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.300792, -118.81205]},
#  {'FacilityID': '233242',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HULL CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [35.968095, -111.946387]},
#  {'FacilityID': '234014',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rio Grande Village Group Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [29.180926, -102.959946]},
#  {'FacilityID': '234013',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Group Sites L-R',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [29.27498117, -103.305057091]},
#  {'FacilityID': '234491',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'PINE FLAT',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-04-10',
#   'Region': 'south_west',
#   'Location': [35.0151210000001, -106.337613]},
#  {'FacilityID': '250019',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'PORTAL BUNKHOUSE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [31.8985527777999, -109.162361111]},
#  {'FacilityID': '232165',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'North',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.342876, -115.683408]},
#  {'FacilityID': '251008',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Crystal Springs Campground Mid-Sized Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.7437021200001, -118.962176]},
#  {'FacilityID': '251436',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.6781789520002, -105.514979571]},
#  {'FacilityID': '232166',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [36.2631657415362, -115.607589878073]},
#  {'FacilityID': '251615',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Bridal Veil Picnic Grounds',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.7663888889001, -120.4825]},
#  {'FacilityID': '251578',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'EQUESTRIAN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_west',
#   'Location': [38.840352, -120.234624]},
#  {'FacilityID': '251841',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Goose Island',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_west',
#   'Location': [38.6123105604996, -109.557367270758]},
#  {'FacilityID': '251825',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'JUMPUP CABIN',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'south_west',
#   'Location': [36.5850000000001, -112.546944444]},
#  {'FacilityID': '252280',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Indian Creek Falls Group Site',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-16',
#   'Region': 'south_west',
#   'Location': [38.205387, -109.674383]}]

# %%
se
# Out:
# [{'FacilityID': '232709',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'REYNOLDS CREEK ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-14',
#   'Region': 'south_east',
#   'Location': [31.586164, -97.264983]},
#  {'FacilityID': '252470',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Dundo Group Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.2352166640001, -78.717593177]},
#  {'FacilityID': '10001451',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-24',
#   'Region': 'south_east',
#   'Location': [36.040823, -93.345717]},
#  {'FacilityID': '259242',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Generator',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233478',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'DAM EAST SPILLWAY',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.616093, -89.3544]},
#  {'FacilityID': '10003508',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-05',
#   'Region': 'south_east',
#   'Location': [32.917917, -85.181022]},
#  {'FacilityID': '258887',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mather',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10004589',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [32.992751, -85.174451]},
#  {'FacilityID': '10004592',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-11',
#   'Region': 'south_east',
#   'Location': [32.917472, -85.191762]},
#  {'FacilityID': '10004594',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [33.028136, -85.177324]},
#  {'FacilityID': '10004596',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [32.959214, -85.150565]},
#  {'FacilityID': '10004598',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [33.058737, -85.119329]},
#  {'FacilityID': '10004600',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-20',
#   'Region': 'south_east',
#   'Location': [32.991655, -85.205619]},
#  {'FacilityID': '10004602',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [32.997826, -85.229038]},
#  {'FacilityID': '10004604',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-25',
#   'Region': 'south_east',
#   'Location': [33.075072, -85.102748]},
#  {'FacilityID': '10004919',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Glamping',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-27',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10005279',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233462',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Beach Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.502001, -95.70761]},
#  {'FacilityID': '10005349',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-06-21',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10005351',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Horseshoe Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-08-23',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10005354',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-04-18',
#   'Region': 'south_east',
#   'Location': [38.117106, -83.536787]},
#  {'FacilityID': '233834',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10005414',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-08',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '234544',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'AREA WILD PLUM',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10005977',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-06-07',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233695',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-20',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10006149',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shelter',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-04-18',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10006204',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10006206',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10007130',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A unit',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-12',
#   'Region': 'south_east',
#   'Location': [38.5635965270001, -77.3592668319999]},
#  {'FacilityID': '246027',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10007156',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233809',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Trace Branch Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-07',
#   'Region': 'south_east',
#   'Location': [37.27164444, -83.37033056]},
#  {'FacilityID': '10007207',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232572',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'DCRP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.30303, -85.911351]},
#  {'FacilityID': '233379',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-12',
#   'Region': 'south_east',
#   'Location': [38.6017089060001, -77.41519909]},
#  {'FacilityID': '251544',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Marsden Tract Group Campsite',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-08',
#   'Region': 'south_east',
#   'Location': [38.976584722, -77.21752001]},
#  {'FacilityID': '10009675',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232746',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'WBEA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-07-12',
#   'Region': 'south_east',
#   'Location': [34.695727, -92.146548]},
#  {'FacilityID': '10011396',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [35.3811441578286, -82.7414021014386]},
#  {'FacilityID': '251963',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'NANCYS BOAT TO SHORE CAMPGROUND (PA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10028678',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Juniper Basin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-26',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232430',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'GRP',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10028991',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'N/A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251431',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A - Tent Only',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-11',
#   'Region': 'south_east',
#   'Location': [35.8000811420001, -75.5445741949999]},
#  {'FacilityID': '251954',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOWER TWIN CAMPGROUND (VA)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10036862',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [39.40816, -88.77364]},
#  {'FacilityID': '10036864',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [39.41104, -88.781]},
#  {'FacilityID': '10036866',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [39.41571, -88.77647]},
#  {'FacilityID': '10036881',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [39.45432, -88.73621]},
#  {'FacilityID': '10036906',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [39.40658, -88.78068]},
#  {'FacilityID': '253502',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rock Creek Campground (TN)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258667',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-16',
#   'Region': 'south_east',
#   'Location': [35.8154908020001, -82.145890755]},
#  {'FacilityID': '10040524',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-18',
#   'Region': 'south_east',
#   'Location': [36.149894, -96.247271]},
#  {'FacilityID': '233410',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-11-03',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10040545',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10040567',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Knightville Picnic Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233598',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-19',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10041495',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-16',
#   'Region': 'south_east',
#   'Location': [35.952875, -96.29116]},
#  {'FacilityID': '10046288',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Upper End',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-11-15',
#   'Region': 'south_east',
#   'Location': [34.421509, -89.730706]},
#  {'FacilityID': '10046915',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-01',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10046994',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BEAVR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-01-05',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10047052',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'CARD',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10047080',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'CHOKE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10047085',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-12-11',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233479',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Overlook',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10048117',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SHENOAH',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-13',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10048193',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'DEWITT',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258992',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-14',
#   'Region': 'south_east',
#   'Location': [37.2019466580001, -86.237345885]},
#  {'FacilityID': '10048983',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'White Oak',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-27',
#   'Region': 'south_east',
#   'Location': [37.2164842490001, -86.0502809229999]},
#  {'FacilityID': '250850',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rockhaven Park Equestrian Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-08-05',
#   'Region': 'south_east',
#   'Location': [38.891197, -95.375342]},
#  {'FacilityID': '10049020',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RedBridge',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10049270',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-03',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10049272',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-09',
#   'Region': 'south_east',
#   'Location': [34.40604943, -89.79910765]},
#  {'FacilityID': '10050271',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-25',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10050273',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'West End Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232024',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'BOX2',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-27',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10050743',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-05',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10052147',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-01',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10052157',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [32.702247, -93.508715]},
#  {'FacilityID': '10052192',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [32.368113, -93.448152]},
#  {'FacilityID': '10053793',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [33.837773, -95.582282]},
#  {'FacilityID': '232615',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KENDALL ANNEX',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-09',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '234053',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop C',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10049434',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-19',
#   'Region': 'south_east',
#   'Location': [35.438939, -94.169729]},
#  {'FacilityID': '10060225',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Main Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-09',
#   'Region': 'south_east',
#   'Location': [34.126431, -89.790571]},
#  {'FacilityID': '10060244',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CRESCENT LAKE (OR)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-19',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10060248',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-05-25',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10060263',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Valley of Fires',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-09',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233425',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BERRY BEND',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-06-07',
#   'Region': 'south_east',
#   'Location': [38.211014, -93.509938]},
#  {'FacilityID': '10060885',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Meadow Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-22',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '274414',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-08',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '234054',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lower Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-08',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258852',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tent Area',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-01-16',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258851',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Tent Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-01-16',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258815',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Hawk Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10067346',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Haypress Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233666',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WCOV',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10068557',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-02',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233679',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-20',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10075441',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Deer Island',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2020-10-15',
#   'Region': 'south_east',
#   'Location': [36.806766, -80.039766]},
#  {'FacilityID': '252970',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Antietam Creek Campsite',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [39.420629702, -77.748339652]},
#  {'FacilityID': '233409',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'NFOR',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-11-03',
#   'Region': 'south_east',
#   'Location': [37.631152, -86.437601]},
#  {'FacilityID': '202162',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Red Cliffs Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232549',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Choctaw',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-31',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232567',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Dam Site',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232573',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Devils Fork',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-31',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232597',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Heber Springs',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-31',
#   'Region': 'south_east',
#   'Location': [35.502803, -92.075914]},
#  {'FacilityID': '232605',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Hill Creek',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-10-10',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232613',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'John F Kennedy',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-03-09',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232649',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Narrows',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-17',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232659',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Old Highway 25',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-22',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232703',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shiloh',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232713',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Sugar Loaf',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232569',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'GROU',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [32.511017, -87.872187]},
#  {'FacilityID': '255240',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'N/A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-03-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233644',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'SUSQUEHANNOCK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-04-09',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10098548',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.401371, -89.793535]},
#  {'FacilityID': '10098551',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Cypress',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-12',
#   'Region': 'south_east',
#   'Location': [34.40065, -89.807701]},
#  {'FacilityID': '10098553',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Engineer',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.396535, -89.784481]},
#  {'FacilityID': '10098555',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Paradise',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.403628, -89.79848]},
#  {'FacilityID': '10098558',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Outlet',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.400151, -89.791778]},
#  {'FacilityID': '10098560',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Outlet Channel',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.157566, -89.907069]},
#  {'FacilityID': '10099358',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Hickory Ridge',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-20',
#   'Region': 'south_east',
#   'Location': [34.159676, -89.896646]},
#  {'FacilityID': '10099484',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'McCurdy Point',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-01',
#   'Region': 'south_east',
#   'Location': [34.159176, -89.898693]},
#  {'FacilityID': '10099489',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-04-26',
#   'Region': 'south_east',
#   'Location': [34.150924, -89.908501]},
#  {'FacilityID': '233442',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Buffalo Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-22',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233610',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Rudds Creek Rec Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233545',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Longwood Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10101311',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Belmont Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_east',
#   'Location': [32.554883, -87.880678]},
#  {'FacilityID': '10101313',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Finches Ferry',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_east',
#   'Location': [32.842577, -87.835339]},
#  {'FacilityID': '10101315',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Lock 6',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_east',
#   'Location': [32.709734, -87.790599]},
#  {'FacilityID': '10101317',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Lock 8',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_east',
#   'Location': [32.895272, -87.780664]},
#  {'FacilityID': '10101319',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Hilltop Shelter',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-09',
#   'Region': 'south_east',
#   'Location': [33.273526, -87.420521]},
#  {'FacilityID': '10101322',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Spillway Falls',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-05-25',
#   'Region': 'south_east',
#   'Location': [32.520408, -87.886899]},
#  {'FacilityID': '10101351',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Dam Area Central',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [33.830438, -89.777559]},
#  {'FacilityID': '10101354',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Grenada Landing',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [33.801626, -89.764097]},
#  {'FacilityID': '10101356',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'South Abutment A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [33.806516, -89.777485]},
#  {'FacilityID': '10101360',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'South Abutment B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [33.809619, -89.773472]},
#  {'FacilityID': '10103087',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [34.568949, -93.192091]},
#  {'FacilityID': '10103089',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [34.570359, -93.214607]},
#  {'FacilityID': '246855',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CCNC',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-16',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10103157',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Island Creek Park',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [36.549782, -78.468231]},
#  {'FacilityID': '10103159',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Ivy Hill Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [36.575477, -78.417038]},
#  {'FacilityID': '10103161',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10103189',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Palmer Point Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [36.56204, -78.288897]},
#  {'FacilityID': '10103191',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [36.601808, -78.299233]},
#  {'FacilityID': '10107303',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-25',
#   'Region': 'south_east',
#   'Location': [32.936933, -85.200283]},
#  {'FacilityID': '10107305',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-25',
#   'Region': 'south_east',
#   'Location': [33.002283, -85.172567]},
#  {'FacilityID': '10107307',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-03-10',
#   'Region': 'south_east',
#   'Location': [32.922033, -85.163333]},
#  {'FacilityID': '10107310',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-02-25',
#   'Region': 'south_east',
#   'Location': [33.094033, -85.06355]},
#  {'FacilityID': '10107534',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Grassy Creek Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [36.537828, -78.596446]},
#  {'FacilityID': '10107536',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Jubilee Lake',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '246037',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Olive Lake',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232303',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'HCMR',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-10-21',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10110659',
#   'CampsiteType': 'View',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Big Hole Lookout',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10110661',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Area Savenac East Cottage',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10110663',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-12-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10113994',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'Birches',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-17',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10114001',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Day',
#   'Loop': 'Cemetery',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10114378',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'LEDGEMERE',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-17',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10116518',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Ledgefork Guard Station',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-01-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10116520',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mill Hollow Guard Station',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-02-03',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10116522',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mirror Lake Guard Station',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-01-19',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10116524',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Soldier Creek Vacation Cabin',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-09-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10116526',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Three Sisters Group Site',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-11-02',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '231931',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'LOOP A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '232075',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'MUEL',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-03',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10119409',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Day',
#   'Loop': 'DAY USE ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-12-06',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10119467',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Chickasaw Hill',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-25',
#   'Region': 'south_east',
#   'Location': [34.162615, -89.826405]},
#  {'FacilityID': '10119469',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': "Ford's Well",
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-25',
#   'Region': 'south_east',
#   'Location': [34.126939, -89.789249]},
#  {'FacilityID': '10119471',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Beach',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.137622, -89.906566]},
#  {'FacilityID': '10119477',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Wallace Creek',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-25',
#   'Region': 'south_east',
#   'Location': [34.164776, -89.887317]},
#  {'FacilityID': '10119479',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Water Valley Landing',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-25',
#   'Region': 'south_east',
#   'Location': [34.141655, -89.764494]},
#  {'FacilityID': '233350',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-03-27',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10120780',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Clear Creek',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-10-05',
#   'Region': 'south_east',
#   'Location': [34.427285, -89.709808]},
#  {'FacilityID': '10120783',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'North Abutment',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-26',
#   'Region': 'south_east',
#   'Location': [33.842874, -89.778373]},
#  {'FacilityID': '10120785',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Hurricane Landing',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-10-05',
#   'Region': 'south_east',
#   'Location': [34.493938, -89.585486]},
#  {'FacilityID': '10120787',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pats Bluff',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-10-05',
#   'Region': 'south_east',
#   'Location': [34.419017, -89.735758]},
#  {'FacilityID': '10120789',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Brady Mountain Day-Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [34.580644, -93.265696]},
#  {'FacilityID': '10120791',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Crystal Springs Day-Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [34.542327, -93.346535]},
#  {'FacilityID': '10120794',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Stephens Park Day-Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-08-30',
#   'Region': 'south_east',
#   'Location': [34.570504, -93.191197]},
#  {'FacilityID': '10120796',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Tompkins Bend Day-Use',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-13',
#   'Region': 'south_east',
#   'Location': [34.56858, -93.4708]},
#  {'FacilityID': '10122577',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-29',
#   'Region': 'south_east',
#   'Location': [34.7387067, -90.1198619]},
#  {'FacilityID': '10122580',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-29',
#   'Region': 'south_east',
#   'Location': [34.7729698, -90.1130012]},
#  {'FacilityID': '10044710',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Atwell Mill',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-18',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10124502',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Azalea',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-04-19',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '246864',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cold Springs',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-30',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10124953',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Wolverton Stock',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10128465',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Big Hurricane - Site 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-05-18',
#   'Region': 'south_east',
#   'Location': [36.021, -85.782]},
#  {'FacilityID': '10128487',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-08-02',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '258706',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rivers Bend',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10130529',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-08',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10130532',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': '01',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-03-04',
#   'Region': 'south_east',
#   'Location': [29.87311, -98.20364]},
#  {'FacilityID': '246796',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mandan',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-21',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10134015',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-21',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10134109',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Gomez Peak Group',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-05-24',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10134111',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'Little Walnut East',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-06-11',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '255177',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'WHITE ROCK MOUNTAIN RECREATION AREA',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.690772, -93.957387]},
#  {'FacilityID': '10145499',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Brickhouse',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-10',
#   'Region': 'south_east',
#   'Location': [34.4480974926003, -81.7058447097258]},
#  {'FacilityID': '10145521',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Woods Ferry',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-10',
#   'Region': 'south_east',
#   'Location': [34.6992185572485, -81.4502729383125]},
#  {'FacilityID': '233257',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Manzanita Glamping Tents',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-07-14',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10147280',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sather Lake',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-09-14',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '246814',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Boca Chita Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-10-05',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10078979',
#   'CampsiteType': 'Water',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Elliot Key Campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-10-05',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '256367',
#   'CampsiteType': 'Hike',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Mosquito River',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-08-05',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '10150477',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Chattahoochee Park',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-21',
#   'Region': 'south_east',
#   'Location': [30.743826, -84.853681]},
#  {'FacilityID': '10150481',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': '',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-29',
#   'Region': 'south_east',
#   'Location': [30.787755, -84.665784]},
#  {'FacilityID': '10150483',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Hales Landing',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-29',
#   'Region': 'south_east',
#   'Location': [30.847136, -84.661542]},
#  {'FacilityID': '10150485',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Rays Lake Park',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2021-09-29',
#   'Region': 'south_east',
#   'Location': [30.836656, -84.850689]},
#  {'FacilityID': '10153246',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Carr Powerhouse Picnic Shelter ',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-02-15',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233267',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'PAVgrp',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2021-11-13',
#   'Region': 'south_east',
# ...
#   'Location': [36.935499, -84.779687]},
#  {'FacilityID': '234754',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'ROCKLAND RECREATION AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.299167, -86.648025]},
#  {'FacilityID': '234744',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SYCAMORE FLATS PICNIC SHELTER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.2745450000001, -82.7118289999999]},
#  {'FacilityID': '234752',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Grant Grove',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '233120',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'OZARK PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.063853479, -93.1605362019999]},
#  {'FacilityID': '233107',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'GROUP SITE',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-05-23',
#   'Region': 'south_east',
#   'Location': [35.999795, -86.472485]},
#  {'FacilityID': '233446',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CADDO DRIVE ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.26007, -93.188877]},
#  {'FacilityID': '234742',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'PINK BEDS PICNIC SHELTER',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.3523870000001, -82.778356]},
#  {'FacilityID': '234643',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'TEJAS PARK',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_east',
#   'Location': [30.69573255, -97.82710403]},
#  {'FacilityID': '233200',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'South Tx Fm 2694',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '234712',
#   'CampsiteType': 'Cabin',
#   'TypeOfUse': 'Day',
#   'Loop': 'SPENCE CABIN',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.65381782, -83.578603481]},
#  {'FacilityID': '233403',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop B',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.4415541990001, -79.602269172]},
#  {'FacilityID': '246890',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'RV NONELECTRIC',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [25.893989306, -81.2299270139999]},
#  {'FacilityID': '249992',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Laurel River Lake Picnic Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.964574, -84.266657]},
#  {'FacilityID': '233138',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sherando Lake Group Camp ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.919208, -79.018334]},
#  {'FacilityID': '233190',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'COLES POINT ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.9450684933989, -79.96920369103]},
#  {'FacilityID': '249997',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Shelters',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '250025',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BOOMER PARK SHELTER',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.093736, -81.278913]},
#  {'FacilityID': '234233',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SHELTERS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-06-19',
#   'Region': 'south_east',
#   'Location': [37.430686, -82.415911]},
#  {'FacilityID': '232442',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'Picnic Area',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.189442876, -86.103031855]},
#  {'FacilityID': '233239',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BOYKIN SPRINGS RECREATION AREA',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [31.0583800000001, -94.27425]},
#  {'FacilityID': '250024',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CHILHOWEE GROUP CAMP',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.1504300000001, -84.6048129999999]},
#  {'FacilityID': '234716',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'TELEGRAPH ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.558301295, -77.3428386309999]},
#  {'FacilityID': '233370',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SPILLWAY GROUP',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.039089, -88.955173]},
#  {'FacilityID': '233139',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Cave Mountain Lake Group Camp ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.5762860000001, -79.53597]},
#  {'FacilityID': '250020',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'BERRY MOUNTAIN PARK SHELTER',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [36.125893, -81.238495]},
#  {'FacilityID': '250034',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'QUINN SPRINGS PAVILION',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.2286722222, -84.5482055556]},
#  {'FacilityID': '250852',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Caesar Creek Lake',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-08-16',
#   'Region': 'south_east',
#   'Location': [39.489686, -84.058657]},
#  {'FacilityID': '233990',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'GATEWOOD GROUP ',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.7194080000001, -79.583012]},
#  {'FacilityID': '250874',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'KV',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.687224, -96.494938]},
#  {'FacilityID': '250988',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'LOFERS BEND DAY USE (TX)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [31.877459, -97.366389]},
#  {'FacilityID': '251263',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Rohrbach campground',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [39.4548287900001, -77.729472713]},
#  {'FacilityID': '251468',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Bear Creek Horse Camp',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251472',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Loop 1',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251453',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'EAST ROLLING HILLS PARK (KS)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [39.07285, -96.905478]},
#  {'FacilityID': '251469',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CURTIS CREEK CAMPGROUND (NC)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.690978, -82.196286]},
#  {'FacilityID': '251450',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'OUTLET PARK (KS)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_east',
#   'Location': [39.076617, -96.885887]},
#  {'FacilityID': '251363',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Ten Mile',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251432',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'NORTH OVERLOOK PARK (KS)',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [39.092036, -96.898737]},
#  {'FacilityID': '251545',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'Carderock Recreation Area Pavilion',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [38.971562933, -77.199743978]},
#  {'FacilityID': '251550',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'OBSERVATION PT',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251534',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'A',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.576749878, -79.336510722]},
#  {'FacilityID': '251624',
#   'CampsiteType': 'Picnic',
#   'TypeOfUse': 'Day',
#   'Loop': 'GREENBELT PARK PICNIC AREAS',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-03-07',
#   'Region': 'south_east',
#   'Location': [38.9935435520001, -76.8901744029999]},
#  {'FacilityID': '234357',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Pulltite Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.334007161, -91.48537756]},
#  {'FacilityID': '251723',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'D Loop',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [35.1517075005982, -84.6047040666318]},
#  {'FacilityID': '234442',
#   'CampsiteType': 'Tent',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Akers Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.376586, -91.563472]},
#  {'FacilityID': '251870',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'COOPER BRANCH No 2 DAY USE AREA (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.17283, -84.733426]},
#  {'FacilityID': '251867',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'RIVERSIDE PARK DAY USE AREA (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.15919, -84.736143]},
#  {'FacilityID': '251835',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Onion Creek',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251837',
#   'CampsiteType': 'Horseback',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Lone Mesa',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251785',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.8373295800001, -81.070379438]},
#  {'FacilityID': '251783',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.829484345, -81.064220335]},
#  {'FacilityID': '251787',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.8357804230001, -81.071602872]},
#  {'FacilityID': '251786',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.8362751500001, -81.070140841]},
#  {'FacilityID': '251784',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'Pavilion',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [37.8341004800001, -81.065565426]},
#  {'FacilityID': '251871',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Day',
#   'Loop': 'SWEETWATER DAY USE AREA (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.19808, -84.574464]},
#  {'FacilityID': '251904',
#   'CampsiteType': 'RV',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'CAMEL LAKE CAMPGROUND',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [30.275475, -84.986483]},
#  {'FacilityID': '251923',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BUFORD DAM PARK SHELTERS (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2023-09-22',
#   'Region': 'south_east',
#   'Location': [34.152434, -84.061539]},
#  {'FacilityID': '251919',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'WEST BANK PARK SHELTERS (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.168178, -84.075012]},
#  {'FacilityID': '251925',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'LITTLE HALL SHELTER (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.313754, -83.945091]},
#  {'FacilityID': '251920',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'THOMPSON CREEK PARK SHELTER (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.353438, -84.019894]},
#  {'FacilityID': '251926',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'LANIER PARK SHELTER (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.152312, -84.057475]},
#  {'FacilityID': '251921',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'BOLDING MILL SHELTERS (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.338352, -83.953628]},
#  {'FacilityID': '251924',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'VAN PUGH NORTH PARK SHELTER (GA)',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [34.187633, -83.979752]},
#  {'FacilityID': '251966',
#   'CampsiteType': 'GROUP PICNIC AREA',
#   'TypeOfUse': 'Day',
#   'Loop': 'SPRING MOUNTAINS VISITOR GATEWAY GROUP PICNIC SITES',
#   'CampsiteAccessible': True,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]},
#  {'FacilityID': '251941',
#   'CampsiteType': 'Shelter',
#   'TypeOfUse': 'Overnight',
#   'Loop': 'Sand Island Group Sites',
#   'CampsiteAccessible': False,
#   'LastUpdatedDate': '2022-06-29',
#   'Region': 'south_east',
#   'Location': [0, 0]}]

# %%
# nws = ','.join(str(x) for x in nw)
# nes = ','.join(str(x) for x in ne)
# sws = ','.join(str(x) for x in sw)
# ses = ','.join(str(x) for x in ne)

# js_out = '{ "NorthWest" = [' + nws + '][ "NorthEast" = [' + nes + '][ "SouthWest" = [' + sws + '][ "SouthEast" = []' + ses + '}'
# js_out = str(js_out)
# js_out = js_out.replace('\\', ' ')

# js_out

# %%
# with open("region_file.js", "w") as fp:
#     json.dump(js_out, fp)

# %%
with open("nw_file.js", "w") as fp:
    json.dump(nw, fp)

# %%
with open("ne_file.js", "w") as fp:
    json.dump(ne, fp)

# %%
with open("sw_file.js", "w") as fp:
    json.dump(sw, fp)

# %%
with open("se_file.js", "w") as fp:
    json.dump(se, fp)

# %%
# Re-establish 'data'
data = json.load(open('data.json', encoding = 'cp850'))

# %%
df = pd.DataFrame(data["RECDATA"])

df

# %%
uf = df['FacilityID'].value_counts()
uf

# %%
unique_df = df.drop_duplicates(subset='FacilityID')
unique_df

# %%
new_df = unique_df[['FacilityID', 'CampsiteType', 'TypeOfUse', 'Loop', 'CampsiteAccessible', 'CampsiteLongitude', 'CampsiteLatitude', 'LastUpdatedDate']]
new_df

# %%
unique2 = new_df["CampsiteType"].unique()
unique2

# %%
new_name = {'RV NONELECTRIC': 'RV',
            'STANDARD NONELECTRIC': '', 
            'RV ELECTRIC': 'RV',
            'SHELTER NONELECTRIC': 'Shelter', 
            'GROUP TENT ONLY AREA NONELECTRIC': 'Tent',
            'STANDARD ELECTRIC': '', 
            'TENT ONLY NONELECTRIC': 'Tent',
       'GROUP SHELTER ELECTRIC': 'Shelter', 
       'CABIN NONELECTRIC': 'Cabin',
       'GROUP SHELTER NONELECTRIC': 'Shelter', 
       'CABIN ELECTRIC': 'Cabin', 
       'YURT': 'Tent',
       'MANAGEMENT': '', 
       'GROUP STANDARD ELECTRIC': '',
       'GROUP RV AREA NONELECTRIC': 'RV', 
       'GROUP STANDARD NONELECTRIC':'',
       'BOAT IN': 'Water', 
       'GROUP STANDARD AREA NONELECTRIC': '', 
       'SHELTER ELECTRIC': 'Shelter',
       'LOOKOUT': 'View', 
       'WALK TO': 'Hike', 
       'PICNIC': 'Picnic', 
       'EQUESTRIAN NONELECTRIC': 'Horseback',
       'HIKE TO': 'Hike', 
       'YES': '',
       'GROUP PICNIC AREA': 'Picnic',
       'OVERNIGHT SHELTER NONELECTRIC': 'Shelter', 
       'PARKING': 'RV', 
       'EQUESTRIAN ELECTRIC':'Horseback',
       'GROUP STANDARD AREA ELECTRIC': '', 
       'OVERNIGHT SHELTER ELECTRIC': 'Shelter',
       'TENT ONLY ELECTRIC': 'Tent', 
       'GROUP WALK TO': 'Hike', 
       'GROUP EQUESTRIAN': 'Horseback',
       'ANCHORAGE': 'Water', 
       'MOORING': '',
        'BALL FIELD': 'Tent' }

# %%
new_df['CampsiteType'] = df['CampsiteType'].replace(new_name)
new_df

# %%
df = new_df[new_df['CampsiteType'].str.strip() != '']
df

# %%
df.to_json('json_data.json', orient='records')

# %%
df.to_csv('csv_data.csv', index = False)
